# %% [markdown]
# # Neo4j Semantic Search Pipeline
#
# This notebook implements a semantic search pipeline using Neo4j and Sentence Transformers. It covers:
# 1.  **Data Loading & Embedding:** Constructing semantic text from flight data and generating embeddings using three different models.
# 2.  **Index Creation:** Creating vector indices in Neo4j.
# 3.  **Search:** Executing a similarity search.

# %%
# Install necessary dependencies
# !pip install neo4j sentence-transformers python-dotenv
# Out:
# Collecting neo4j
#   Downloading neo4j-6.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.53.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Downloading neo4j-6.0.3-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 9.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.4 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.2 MB/s eta 0:00:0000:0100:01m
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.6 MB/s eta 0:00:00:00:010:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, neo4j, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed neo4j-6.0.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
os.environ['NEO4J_URI'] = '---'
os.environ['NEO4J_USERNAME'] = '---'
os.environ['NEO4J_PASSWORD'] = '---'

# %% [markdown]
# ## Part 1: Load Models & Process Data
# This step fetches journey data, creates descriptive text, generates embeddings (MiniLM, MPNet, BGE-M3), and stores them in `JourneyVector` nodes.

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os

# ------------------------------
# 1. Load Embedding Models
# ------------------------------
print("Loading embedding models...")
# Loading all three as requested
model_minilm = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
model_mpnet = SentenceTransformer("sentence-transformers/paraphrase-mpnet-base-v2")
model_bge_m3 = SentenceTransformer("BAAI/bge-m3")

# ------------------------------
# 2. Neo4j Connection
# ------------------------------
uri = os.getenv('NEO4J_URI')
username = os.getenv('NEO4J_USERNAME')
password = os.getenv('NEO4J_PASSWORD')

driver = GraphDatabase.driver(uri, auth=(username, password))

# ------------------------------
# Helper: Semantic Text Builder
# ------------------------------
def build_semantic_text(record):
    """
    Constructs a qualitative narrative using the provided airline metrics.
    """
    # --- Delay Context ---
    delay = record['arrival_delay_minutes']
    # Metrics: avg ~ -1.4, max ~ 880. >60 is definitely severe.
    if delay <= 0:
        delay_desc = f"arrived early by {abs(delay)} minutes"
        punctuality = "highly punctual"
    elif delay <= 15:
        delay_desc = f"was roughly on time ({delay} min delay)"
        punctuality = "punctual"
    elif delay <= 60:
        delay_desc = f"had a moderate delay of {delay} minutes"
        punctuality = "delayed"
    else:
        delay_desc = f"suffered a severe delay of {delay} minutes"
        punctuality = "severely delayed"

    # --- Food Context ---
    # Metrics: avg ~ 2.8, max 5.
    score = record['food_satisfaction_score']
    if score <= 2:
        food_desc = "poor dining experience"
    elif score == 3:
        food_desc = "average dining experience"
    else:
        food_desc = "excellent dining experience"

    # --- Distance Context ---
    # Metrics: avg ~ 2237, max ~ 8440.
    miles = record['actual_flown_miles']
    if miles < 1000:
        haul = "short-haul"
    elif miles < 4000:
        haul = "medium-haul"
    else:
        haul = "long-haul"

    # --- Construct the Sentence ---
    # We embed "Concept" + "Details"
    text = (
        f"A {punctuality} {haul} flight. "
        f"The {record['passenger_class']} journey covered {miles} miles on a {record['fleet_type_description']} aircraft. "
        f"It {delay_desc}. "
        f"The passenger (Generation: {record['generation']}, Status: {record['loyalty_program_level']}) "
        f"reported a {food_desc} with a rating of {score}/5. "
        f"Route: {record['origin']} to {record['destination']}."
    )
    return text

# ------------------------------
# 3. Processing Pipeline
# ------------------------------
def process(tx):
    print("Fetching journey data...")
    # We grab the ID to link specifically to this Journey
    result = tx.run("""
        MATCH (p:Passenger)-[:TOOK]->(j:Journey)-[:ON]->(f:Flight)
        MATCH (f)-[:DEPARTS_FROM]->(dep:Airport)
        MATCH (f)-[:ARRIVES_AT]->(arr:Airport)
        RETURN
            j.feedback_ID AS feedback_ID,
            p.record_locator AS record_locator,
            p.generation AS generation,
            p.loyalty_program_level AS loyalty_program_level,
            j.food_satisfaction_score AS food_satisfaction_score,
            j.arrival_delay_minutes AS arrival_delay_minutes,
            j.actual_flown_miles AS actual_flown_miles,
            j.passenger_class AS passenger_class,
            f.fleet_type_description AS fleet_type_description,
            dep.station_code AS origin,
            arr.station_code AS destination
    """)
    
    records = list(result)
    print(f"Found {len(records)} journeys to embed.")

    for i, row in enumerate(records):
        # 1. Build rich text
        text = build_semantic_text(row)

        # 2. Generate embeddings
        emb_minilm = model_minilm.encode(text).tolist()
        emb_mpnet = model_mpnet.encode(text).tolist()
        emb_bge_m3 = model_bge_m3.encode(text).tolist()

        # 3. Store in SEPARATE Node (:JourneyVector)
        # We link via feedback_ID.
        tx.run("""
            MATCH (j:Journey {feedback_ID: $fid})
            
            // Create/Merge the Vector Node
            // We ID it by the journey ID + suffix to ensure 1:1 mapping
            MERGE (jv:JourneyVector {id: $fid + '_vec'})
            ON CREATE SET 
                jv.text = $text,
                jv.minilm_embedding = $e1,
                jv.mpnet_embedding = $e2,
                jv.bgem3_embedding = $e3
            ON MATCH SET
                jv.text = $text,
                jv.minilm_embedding = $e1,
                jv.mpnet_embedding = $e2,
                jv.bgem3_embedding = $e3
            
            // Link it
            MERGE (j)-[:HAS_VECTOR]->(jv)
        """, 
        fid=row['feedback_ID'],
        text=text,
        e1=emb_minilm, 
        e2=emb_mpnet, 
        e3=emb_bge_m3)

        if i % 50 == 0:
            print(f"Processed {i}/{len(records)}...")

with driver.session() as session:
    session.execute_write(process)

print("Done! Vectors stored in 'JourneyVector' nodes.")
# Out:
# Loading embedding models...
# Fetching journey data...
# Found 3132 journeys to embed.
# Processed 0/3132...
# Processed 50/3132...
# Processed 100/3132...
# Processed 150/3132...
# Processed 200/3132...
# Processed 250/3132...
# Processed 300/3132...
# Processed 350/3132...
# Processed 400/3132...
# Processed 450/3132...
# Processed 500/3132...
# Processed 550/3132...
# Processed 600/3132...
# Processed 650/3132...
# Processed 700/3132...
# Processed 750/3132...
# Processed 800/3132...
# Processed 850/3132...
# Processed 900/3132...
# Processed 950/3132...
# Processed 1000/3132...
# Processed 1050/3132...
# Processed 1100/3132...
# Processed 1150/3132...
# Processed 1200/3132...
# Processed 1250/3132...
# Processed 1300/3132...
# Processed 1350/3132...
# Processed 1400/3132...
# Processed 1450/3132...
# Processed 1500/3132...
# Processed 1550/3132...
# Processed 1600/3132...
# Processed 1650/3132...
# Processed 1700/3132...
# Processed 1750/3132...
# Processed 1800/3132...
# Processed 1850/3132...
# Processed 1900/3132...
# Processed 1950/3132...
# Processed 2000/3132...
# Processed 2050/3132...
# Processed 2100/3132...
# Processed 2150/3132...
# Processed 2200/3132...
# Processed 2250/3132...
# Processed 2300/3132...
# Processed 2350/3132...
# Processed 2400/3132...
# Processed 2450/3132...
# Processed 2500/3132...
# Processed 2550/3132...
# Processed 2600/3132...
# Processed 2650/3132...
# Processed 2700/3132...
# Processed 2750/3132...
# Processed 2800/3132...
# Processed 2850/3132...
# Processed 2900/3132...
# Processed 2950/3132...
# Processed 3000/3132...
# Processed 3050/3132...
# Processed 3100/3132...
# Done! Vectors stored in 'JourneyVector' nodes.

# %% [markdown]
# ## Part 2: Create Indices
# Creates Vector Indices in Neo4j for the three different embedding models.

# %%
from neo4j import GraphDatabase
import os

uri = os.getenv('NEO4J_URI')
username = os.getenv('NEO4J_USERNAME')
password = os.getenv('NEO4J_PASSWORD')

driver = GraphDatabase.driver(uri, auth=(username, password))

def create_indices():
    with driver.session() as session:
        print("Creating indices on :JourneyVector...")

        # 1. MiniLM
        session.run("""
            CREATE VECTOR INDEX minilm_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.minilm_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 384, `vector.similarity_function`: 'cosine'}}
        """)
        
        # 2. MPNet
        session.run("""
            CREATE VECTOR INDEX mpnet_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.mpnet_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 768, `vector.similarity_function`: 'cosine'}}
        """)

        # 3. BGE-M3
        session.run("""
            CREATE VECTOR INDEX bgem3_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.bgem3_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 1024, `vector.similarity_function`: 'cosine'}}
        """)

        print("Indices created successfully.")

if __name__ == "__main__":
    create_indices()
# Out:
# Creating indices on :JourneyVector...
# Indices created successfully.

# %% [markdown]
# ## Part 3: Semantic Search Test
# Performs a test search using the MiniLM model.

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os 
from dotenv import load_dotenv

load_dotenv()

# We'll test with MiniLM for speed
model = SentenceTransformer("BAAI/bge-m3")

uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
username = os.getenv('NEO4J_USERNAME', 'neo4j')
password = os.getenv('NEO4J_PASSWORD', 'password')
driver = GraphDatabase.driver(uri, auth=(username, password))

def search(query, top_k=3):
    embedding = model.encode(query).tolist()
    
    cypher = """
    CALL db.index.vector.queryNodes('bgem3_vec_index', $k, $vec)
    YIELD node, score
    
    MATCH (j:Journey)-[:HAS_VECTOR]->(node)
    MATCH (p:Passenger)-[:TOOK]->(j)
    
    RETURN 
        score,
        node.text AS semantic_text,
        j.feedback_ID AS feedback_id,
        j.arrival_delay_minutes AS actual_delay,
        j.food_satisfaction_score AS actual_food
    """
    
    with driver.session() as session:
        result = session.run(cypher, k=top_k, vec=embedding)
        return [dict(r) for r in result]

if __name__ == "__main__":
    print("--- Testing Semantic Search ---")
    q = "big delays and bad food"
    print(f"Query: '{q}'")
    
    results = search(q)
    for r in results:
        print(f"\nScore: {r['score']:.4f}")
        print(f"Text: {r['semantic_text']}")
        print(f"DB Check -> Delay: {r['actual_delay']}, Food: {r['actual_food']}")
# Out:
# --- Testing Semantic Search ---
# Query: 'big delays and bad food'
#
# Score: 0.8155
# Text: A severely delayed short-haul flight. The Economy journey covered 126 miles on a CRJ-700 aircraft. It suffered a severe delay of 76 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: ASX to DEX.
# DB Check -> Delay: 76, Food: 1
#
# Score: 0.8137
# Text: A severely delayed short-haul flight. The Economy journey covered 190 miles on a ERJ-175 aircraft. It suffered a severe delay of 125 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SBX to SFX.
# DB Check -> Delay: 125, Food: 2
#
# Score: 0.8128
# Text: A severely delayed short-haul flight. The Economy journey covered 372 miles on a A320-200 aircraft. It suffered a severe delay of 90 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: SFX to SNX.
# DB Check -> Delay: 90, Food: 1

# %% [markdown]
# ## Comparitive Analysis

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os
from dotenv import load_dotenv

load_dotenv()

# ---------------------------------------------------------
# 1. SETUP: Load All 3 Models
# ---------------------------------------------------------
print("Loading models... (This might take a minute)")
models = {
    "minilm": {
        "model": SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2"),
        "index": "minilm_vec_index"
    },
    "mpnet": {
        "model": SentenceTransformer("sentence-transformers/paraphrase-mpnet-base-v2"),
        "index": "mpnet_vec_index"
    },
    "bge-m3": {
        "model": SentenceTransformer("BAAI/bge-m3"),
        "index": "bgem3_vec_index"
    }
}

uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
username = os.getenv('NEO4J_USERNAME', 'neo4j')
password = os.getenv('NEO4J_PASSWORD', 'password')
driver = GraphDatabase.driver(uri, auth=(username, password))


QUESTIONS = [
    "Q1: flights with severe delays and terrible food",
    "Q2: excellent dining experience on a short flight",
    "Q3: unhappy passengers on Boeing aircraft",
    "Q4: Millennial generation complaining about delays",
    "Q5: Premier Gold members with poor satisfaction",
    "Q6: The food was great but the flight was late",
    "Q7: long haul flights that arrived early",
    "Q8: Economy class passengers who had a good time",
    "Q9: nightmare journey with huge delay over 3 hours",
    "Q10: smooth trip with no issues",
    "Q11: Show me the delay for a flight out of JNX", 
    "Q12: Boomers who had excellent food", 
    "Q13: Satisfied Premier Gold members in Economy", 
    "Q14: Find all flights from JNX to EWX longer than 2000 miles.", 
    "Q15: Gen X passengers flying on the A320-200", 
    "Q16: Flights out of SEX", 
    "Q17: Flights from SEX to IAX"
    
]

# ---------------------------------------------------------
# 3. SEARCH LOGIC
# ---------------------------------------------------------
def search(query, model_key, top_k=3):
    model_obj = models[model_key]["model"]
    index_name = models[model_key]["index"]
    
    embedding = model_obj.encode(query).tolist()
    
    cypher = f"""
    CALL db.index.vector.queryNodes('{index_name}', $k, $vec)
    YIELD node, score
    
    MATCH (j:Journey)-[:HAS_VECTOR]->(node)
    
    RETURN 
        score,
        node.text AS semantic_text,
        j.arrival_delay_minutes AS actual_delay,
        j.food_satisfaction_score AS actual_food
    """
    
    with driver.session() as session:
        result = session.run(cypher, k=top_k, vec=embedding)
        return [dict(r) for r in result]

# ---------------------------------------------------------
# 4. EXECUTION LOOP
# ---------------------------------------------------------
if __name__ == "__main__":
    print("\n=== STARTING 3-MODEL COMPARISON (Top 3 Results) ===\n")

    for q in QUESTIONS:
        print(f"_"*80)
        print(f"QUERY: {q}")
        print(f"_"*80)
        
        for model_name in ["minilm", "mpnet", "bge-m3"]:
            print(f"\n--- MODEL: {model_name.upper()} ---")
            try:
                results = search(q, model_name, top_k=3)
                
                if not results:
                    print("  No results found.")
                    continue

                for i, r in enumerate(results):
                    print(f"  #{i+1} [Score: {r['score']:.4f}]")
                    # Truncate text to keep output clean
                    clean_text = r['semantic_text']
                    print(f"     Text: \"{clean_text}\"")
                    print(f"     Stats: Delay={r['actual_delay']}min | Food={r['actual_food']}/5")
                
            except Exception as e:
                print(f"  Error: {e}")
        
        print("\n")
# Out:
# Loading models... (This might take a minute)
#
# === STARTING 3-MODEL COMPARISON (Top 3 Results) ===
#
# ________________________________________________________________________________
# QUERY: Q1: flights with severe delays and terrible food
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7914]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1745 miles on a B757-300 aircraft. It suffered a severe delay of 162 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to ORX."
#      Stats: Delay=162min | Food=1/5
#   #2 [Score: 0.7859]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1754 miles on a B737-900 aircraft. It suffered a severe delay of 61 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: DEX to BOX."
#      Stats: Delay=61min | Food=1/5
#   #3 [Score: 0.7815]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1557 miles on a B737-800 aircraft. It suffered a severe delay of 181 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: PHX to DEX."
#      Stats: Delay=181min | Food=3/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8754]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 8440 miles on a B787-9 aircraft. It suffered a severe delay of 63 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: SFX to SIX."
#      Stats: Delay=63min | Food=1/5
#   #2 [Score: 0.8709]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: FCX to IAX."
#      Stats: Delay=62min | Food=1/5
#   #3 [Score: 0.8709]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4082 miles on a B777-200 aircraft. It suffered a severe delay of 77 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: IAX to FRX."
#      Stats: Delay=77min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8289]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 5233 miles on a B777-200 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Route: IAX to FRX."
#      Stats: Delay=62min | Food=1/5
#   #2 [Score: 0.8288]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 5889 miles on a B777-300 aircraft. It suffered a severe delay of 73 minutes. The passenger (Generation: Gen X, Status: premier platinum) reported a poor dining experience with a rating of 1/5. Route: MUX to SFX."
#      Stats: Delay=73min | Food=1/5
#   #3 [Score: 0.8281]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4834 miles on a B777-200 aircraft. It suffered a severe delay of 66 minutes. The passenger (Generation: Gen X, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: IAX to LHX."
#      Stats: Delay=66min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q2: excellent dining experience on a short flight
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7663]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1721 miles on a B737-900 aircraft. It arrived early by 25 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: ORX to SEX."
#      Stats: Delay=-25min | Food=4/5
#   #2 [Score: 0.7643]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1721 miles on a B737-900 aircraft. It arrived early by 30 minutes. The passenger (Generation: Boomer, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Route: SEX to ORX."
#      Stats: Delay=-30min | Food=5/5
#   #3 [Score: 0.7638]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1874 miles on a B737-900 aircraft. It arrived early by 18 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Route: IAX to SEX."
#      Stats: Delay=-18min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8581]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 967 miles on a B737-800 aircraft. It arrived early by 4 minutes. The passenger (Generation: Gen X, Status: premier silver) reported a excellent dining experience with a rating of 5/5. Route: DEX to SFX."
#      Stats: Delay=-4min | Food=5/5
#   #2 [Score: 0.8558]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 678 miles on a B737-800 aircraft. It arrived early by 22 minutes. The passenger (Generation: Millennial, Status: premier gold) reported a average dining experience with a rating of 3/5. Route: SFX to SEX."
#      Stats: Delay=-22min | Food=3/5
#   #3 [Score: 0.8552]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 678 miles on a B737-800 aircraft. It arrived early by 19 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: SEX to SFX."
#      Stats: Delay=-19min | Food=5/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8473]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 602 miles on a A320-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: PHX to DEX."
#      Stats: Delay=-9min | Food=4/5
#   #2 [Score: 0.8455]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 602 miles on a A320-200 aircraft. It arrived early by 2 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: PHX to DEX."
#      Stats: Delay=-2min | Food=1/5
#   #3 [Score: 0.8455]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 602 miles on a B737-900 aircraft. It arrived early by 12 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: PHX to DEX."
#      Stats: Delay=-12min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q3: unhappy passengers on Boeing aircraft
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7279]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1009 miles on a B737-900 aircraft. It arrived early by 10 minutes. The passenger (Generation: Silent, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: IAX to PHX."
#      Stats: Delay=-10min | Food=3/5
#   #2 [Score: 0.7217]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1120 miles on a B737-MAX9 aircraft. It suffered a severe delay of 203 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: RSX to ORX."
#      Stats: Delay=203min | Food=1/5
#   #3 [Score: 0.7189]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1009 miles on a B737-MAX8 aircraft. It arrived early by 13 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: PHX to IAX."
#      Stats: Delay=-13min | Food=3/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8008]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 3096 miles on a B757-200 aircraft. It suffered a severe delay of 124 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: EWX to SNX."
#      Stats: Delay=124min | Food=2/5
#   #2 [Score: 0.7991]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: FCX to IAX."
#      Stats: Delay=62min | Food=1/5
#   #3 [Score: 0.7985]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4526 miles on a B767-300 aircraft. It suffered a severe delay of 65 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a poor dining experience with a rating of 2/5. Route: DBX to EWX."
#      Stats: Delay=65min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7825]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2298 miles on a B737-900 aircraft. It had a moderate delay of 45 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: ORX to AUX."
#      Stats: Delay=45min | Food=2/5
#   #2 [Score: 0.7807]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1241 miles on a B737-800 aircraft. It was roughly on time (8 min delay). The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to AUX."
#      Stats: Delay=8min | Food=1/5
#   #3 [Score: 0.7807]
#      Text: "A delayed medium-haul flight. The Economy journey covered 1208 miles on a B737-800 aircraft. It had a moderate delay of 35 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: IAX to DCX."
#      Stats: Delay=35min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q4: Millennial generation complaining about delays
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7077]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1958 miles on a B737-900 aircraft. It suffered a severe delay of 177 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: EWX to AUX."
#      Stats: Delay=177min | Food=3/5
#   #2 [Score: 0.7056]
#      Text: "A delayed medium-haul flight. The Economy journey covered 1605 miles on a B737-900 aircraft. It had a moderate delay of 49 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: EWX to DEX."
#      Stats: Delay=49min | Food=1/5
#   #3 [Score: 0.7039]
#      Text: "A severely delayed short-haul flight. The Economy journey covered 200 miles on a B737-800 aircraft. It suffered a severe delay of 85 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: EWX to BOX."
#      Stats: Delay=85min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7185]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4082 miles on a B777-200 aircraft. It suffered a severe delay of 77 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: IAX to FRX."
#      Stats: Delay=77min | Food=2/5
#   #2 [Score: 0.7115]
#      Text: "A delayed long-haul flight. The Economy journey covered 5368 miles on a B777-200 aircraft. It had a moderate delay of 44 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to LHX."
#      Stats: Delay=44min | Food=2/5
#   #3 [Score: 0.7113]
#      Text: "A severely delayed short-haul flight. The Economy journey covered 717 miles on a B737-800 aircraft. It suffered a severe delay of 234 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: MIX to IAX."
#      Stats: Delay=234min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7755]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2419 miles on a B737-900 aircraft. It had a moderate delay of 16 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: IAX to SFX."
#      Stats: Delay=16min | Food=2/5
#   #2 [Score: 0.7740]
#      Text: "A delayed medium-haul flight. The Economy journey covered 1498 miles on a ERJ-175 aircraft. It had a moderate delay of 47 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to MCX."
#      Stats: Delay=47min | Food=2/5
#   #3 [Score: 0.7736]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2288 miles on a B737-900 aircraft. It had a moderate delay of 40 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to IAX."
#      Stats: Delay=40min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q5: Premier Gold members with poor satisfaction
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6338]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1086 miles on a A319-100 aircraft. It was roughly on time (5 min delay). The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: EWX to MIX."
#      Stats: Delay=5min | Food=2/5
#   #2 [Score: 0.6257]
#      Text: "A punctual long-haul flight. The Economy journey covered 5692 miles on a B787-10 aircraft. It was roughly on time (8 min delay). The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Route: EWX to TLX."
#      Stats: Delay=8min | Food=1/5
#   #3 [Score: 0.6242]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5692 miles on a B787-10 aircraft. It arrived early by 24 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: EWX to TLX."
#      Stats: Delay=-24min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6776]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1747 miles on a B737-900 aircraft. It arrived early by 20 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: YYX to IAX."
#      Stats: Delay=-20min | Food=2/5
#   #2 [Score: 0.6769]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 2 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: SEX to IAX."
#      Stats: Delay=-2min | Food=2/5
#   #3 [Score: 0.6739]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1117 miles on a B737-MAX8 aircraft. It arrived early by 2 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: PIX to IAX."
#      Stats: Delay=-2min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7395]
#      Text: "A delayed short-haul flight. The Economy journey covered 337 miles on a B757-200 aircraft. It had a moderate delay of 33 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 1/5. Route: LAX to SFX."
#      Stats: Delay=33min | Food=1/5
#   #2 [Score: 0.7379]
#      Text: "A delayed short-haul flight. The Economy journey covered 775 miles on a A320-200 aircraft. It had a moderate delay of 28 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: DEX to AUX."
#      Stats: Delay=28min | Food=2/5
#   #3 [Score: 0.7365]
#      Text: "A delayed short-haul flight. The Economy journey covered 867 miles on a A319-100 aircraft. It had a moderate delay of 16 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: BOX to ORX."
#      Stats: Delay=16min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q6: The food was great but the flight was late
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7473]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1745 miles on a B737-900 aircraft. It arrived early by 22 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: ORX to LAX."
#      Stats: Delay=-22min | Food=5/5
#   #2 [Score: 0.7424]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1745 miles on a B737-900 aircraft. It arrived early by 25 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a poor dining experience with a rating of 2/5. Route: LAX to ORX."
#      Stats: Delay=-25min | Food=2/5
#   #3 [Score: 0.7424]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1745 miles on a B737-900 aircraft. It arrived early by 34 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: ORX to LAX."
#      Stats: Delay=-34min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8540]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5473 miles on a B787-9 aircraft. It arrived early by 6 minutes. The passenger (Generation: Millennial, Status: premier gold) reported a poor dining experience with a rating of 1/5. Route: SFX to AMX."
#      Stats: Delay=-6min | Food=1/5
#   #2 [Score: 0.8537]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It arrived early by 24 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: IAX to FCX."
#      Stats: Delay=-24min | Food=1/5
#   #3 [Score: 0.8530]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5473 miles on a B787-9 aircraft. It arrived early by 1 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to AMX."
#      Stats: Delay=-1min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8288]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 6469 miles on a B777-300 aircraft. It arrived early by 26 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to TPX."
#      Stats: Delay=-26min | Food=2/5
#   #2 [Score: 0.8274]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 6469 miles on a B777-300 aircraft. It arrived early by 21 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: TPX to SFX."
#      Stats: Delay=-21min | Food=1/5
#   #3 [Score: 0.8262]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 6469 miles on a B777-300 aircraft. It arrived early by 29 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to TPX."
#      Stats: Delay=-29min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q7: long haul flights that arrived early
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.8274]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2556 miles on a B737-900 aircraft. It arrived early by 15 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: LAX to HNX."
#      Stats: Delay=-15min | Food=2/5
#   #2 [Score: 0.8247]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2556 miles on a B737-800 aircraft. It arrived early by 31 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to HNX."
#      Stats: Delay=-31min | Food=1/5
#   #3 [Score: 0.8239]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2556 miles on a B777-200 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to HNX."
#      Stats: Delay=-7min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8531]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5473 miles on a B787-9 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: premier 1k) reported a poor dining experience with a rating of 1/5. Route: SFX to AMX."
#      Stats: Delay=-6min | Food=1/5
#   #2 [Score: 0.8528]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5473 miles on a B787-9 aircraft. It arrived early by 6 minutes. The passenger (Generation: Millennial, Status: premier gold) reported a poor dining experience with a rating of 1/5. Route: SFX to AMX."
#      Stats: Delay=-6min | Food=1/5
#   #3 [Score: 0.8527]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It arrived early by 12 minutes. The passenger (Generation: Boomer, Status: premier platinum) reported a poor dining experience with a rating of 1/5. Route: FCX to IAX."
#      Stats: Delay=-12min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8172]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4292 miles on a B777-200 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: FCX to EWX."
#      Stats: Delay=-7min | Food=5/5
#   #2 [Score: 0.8169]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4010 miles on a B777-200 aircraft. It arrived early by 7 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: EWX to MXX."
#      Stats: Delay=-7min | Food=5/5
#   #3 [Score: 0.8143]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5368 miles on a B777-200 aircraft. It arrived early by 21 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: LHX to SFX."
#      Stats: Delay=-21min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q8: Economy class passengers who had a good time
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7705]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2119 miles on a B737-900 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: LAX to CUX."
#      Stats: Delay=-6min | Food=2/5
#   #2 [Score: 0.7680]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2119 miles on a B737-900 aircraft. It arrived early by 11 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: LAX to CUX."
#      Stats: Delay=-11min | Food=3/5
#   #3 [Score: 0.7668]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2053 miles on a B737-800 aircraft. It arrived early by 4 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: CLX to LAX."
#      Stats: Delay=-4min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7900]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1222 miles on a B737-MAX8 aircraft. It arrived early by 11 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: IAX to LAX."
#      Stats: Delay=-11min | Food=5/5
#   #2 [Score: 0.7880]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2486 miles on a B737-MAX9 aircraft. It arrived early by 12 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: OGX to LAX."
#      Stats: Delay=-12min | Food=4/5
#   #3 [Score: 0.7878]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2227 miles on a B737-900 aircraft. It arrived early by 1 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: EWX to LAX."
#      Stats: Delay=-1min | Food=5/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8426]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1222 miles on a B737-MAX8 aircraft. It arrived early by 12 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a excellent dining experience with a rating of 5/5. Route: IAX to LAX."
#      Stats: Delay=-12min | Food=5/5
#   #2 [Score: 0.8424]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2227 miles on a B737-MAX8 aircraft. It arrived early by 8 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: LAX to EWX."
#      Stats: Delay=-8min | Food=5/5
#   #3 [Score: 0.8422]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1222 miles on a B737-MAX8 aircraft. It arrived early by 11 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: IAX to LAX."
#      Stats: Delay=-11min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q9: nightmare journey with huge delay over 3 hours
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7552]
#      Text: "A severely delayed short-haul flight. The Economy journey covered 200 miles on a B737-800 aircraft. It suffered a severe delay of 85 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: EWX to BOX."
#      Stats: Delay=85min | Food=1/5
#   #2 [Score: 0.7512]
#      Text: "A severely delayed short-haul flight. The Economy journey covered 717 miles on a B737-800 aircraft. It suffered a severe delay of 115 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: IAX to MIX."
#      Stats: Delay=115min | Food=4/5
#   #3 [Score: 0.7510]
#      Text: "A severely delayed short-haul flight. The Economy journey covered 719 miles on a B737-900 aircraft. It suffered a severe delay of 109 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: ORX to EWX."
#      Stats: Delay=109min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8108]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: FCX to IAX."
#      Stats: Delay=62min | Food=1/5
#   #2 [Score: 0.8107]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 5417 miles on a B767-300 aircraft. It suffered a severe delay of 145 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: MUX to IAX."
#      Stats: Delay=145min | Food=2/5
#   #3 [Score: 0.8082]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 5417 miles on a B767-300 aircraft. It suffered a severe delay of 183 minutes. The passenger (Generation: Boomer, Status: premier 1k) reported a poor dining experience with a rating of 2/5. Route: IAX to MUX."
#      Stats: Delay=183min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8271]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 8440 miles on a B787-9 aircraft. It suffered a severe delay of 63 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: SFX to SIX."
#      Stats: Delay=63min | Food=1/5
#   #2 [Score: 0.8205]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 7853 miles on a B787-9 aircraft. It suffered a severe delay of 104 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: MEX to SFX."
#      Stats: Delay=104min | Food=1/5
#   #3 [Score: 0.8186]
#      Text: "A severely delayed long-haul flight. The Economy journey covered 8440 miles on a B787-9 aircraft. It suffered a severe delay of 620 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: SFX to SIX."
#      Stats: Delay=620min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q10: smooth trip with no issues
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6953]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 1745 miles on a B757-300 aircraft. It suffered a severe delay of 162 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LAX to ORX."
#      Stats: Delay=162min | Food=1/5
#   #2 [Score: 0.6938]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 2944 miles on a B757-200 aircraft. It suffered a severe delay of 87 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: ORX to KEX."
#      Stats: Delay=87min | Food=5/5
#   #3 [Score: 0.6918]
#      Text: "A delayed short-haul flight. The Economy journey covered 67 miles on a CRJ-700 aircraft. It had a moderate delay of 35 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: MKX to ORX."
#      Stats: Delay=35min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7466]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5062 miles on a B777-200 aircraft. It arrived early by 23 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: EZX to IAX."
#      Stats: Delay=-23min | Food=4/5
#   #2 [Score: 0.7463]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3946 miles on a B767-300 aircraft. It arrived early by 9 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: ZRX to EWX."
#      Stats: Delay=-9min | Food=5/5
#   #3 [Score: 0.7462]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5062 miles on a B777-200 aircraft. It arrived early by 18 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: EZX to IAX."
#      Stats: Delay=-18min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7867]
#      Text: "A punctual medium-haul flight. The Economy journey covered 3385 miles on a B787-10 aircraft. It was roughly on time (2 min delay). The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: LIX to EWX."
#      Stats: Delay=2min | Food=5/5
#   #2 [Score: 0.7847]
#      Text: "A punctual long-haul flight. The Economy journey covered 4160 miles on a B787-10 aircraft. It was roughly on time (10 min delay). The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: BRX to ORX."
#      Stats: Delay=10min | Food=4/5
#   #3 [Score: 0.7839]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4530 miles on a B787-10 aircraft. It arrived early by 10 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: MUX to ORX."
#      Stats: Delay=-10min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q11: Show me the delay for a flight out of JNX
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7903]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2399 miles on a B777-200 aircraft. It had a moderate delay of 38 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: SFX to HNX."
#      Stats: Delay=38min | Food=1/5
#   #2 [Score: 0.7888]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2399 miles on a B777-200 aircraft. It had a moderate delay of 47 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to HNX."
#      Stats: Delay=47min | Food=2/5
#   #3 [Score: 0.7885]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2399 miles on a B777-200 aircraft. It had a moderate delay of 47 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: SFX to HNX."
#      Stats: Delay=47min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8287]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2704 miles on a B737-MAX9 aircraft. It had a moderate delay of 55 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a poor dining experience with a rating of 2/5. Route: BOX to SFX."
#      Stats: Delay=55min | Food=2/5
#   #2 [Score: 0.8283]
#      Text: "A delayed short-haul flight. The Economy journey covered 733 miles on a A319-100 aircraft. It had a moderate delay of 38 minutes. The passenger (Generation: Gen Z, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: ORX to LGX."
#      Stats: Delay=38min | Food=1/5
#   #3 [Score: 0.8268]
#      Text: "A delayed long-haul flight. The Economy journey covered 5473 miles on a B787-9 aircraft. It had a moderate delay of 23 minutes. The passenger (Generation: Gen X, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: AMX to SFX."
#      Stats: Delay=23min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8124]
#      Text: "A delayed medium-haul flight. The Economy journey covered 3365 miles on a B777-200 aircraft. It had a moderate delay of 26 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a average dining experience with a rating of 3/5. Route: HNX to DEX."
#      Stats: Delay=26min | Food=3/5
#   #2 [Score: 0.8121]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2399 miles on a B777-200 aircraft. It had a moderate delay of 47 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: SFX to HNX."
#      Stats: Delay=47min | Food=2/5
#   #3 [Score: 0.8114]
#      Text: "A severely delayed medium-haul flight. The Economy journey covered 3365 miles on a B777-200 aircraft. It suffered a severe delay of 89 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a average dining experience with a rating of 3/5. Route: HNX to DEX."
#      Stats: Delay=89min | Food=3/5
#
#
# ________________________________________________________________________________
# QUERY: Q12: Boomers who had excellent food
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6720]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1944 miles on a B737-800 aircraft. It arrived early by 20 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: INX to SFX."
#      Stats: Delay=-20min | Food=2/5
#   #2 [Score: 0.6633]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1958 miles on a B737-900 aircraft. It arrived early by 15 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: EWX to AUX."
#      Stats: Delay=-15min | Food=2/5
#   #3 [Score: 0.6626]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1877 miles on a B737-900 aircraft. It arrived early by 19 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: IAX to AUX."
#      Stats: Delay=-19min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7105]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2133 miles on a A320-200 aircraft. It arrived early by 10 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: PHX to EWX."
#      Stats: Delay=-10min | Food=3/5
#   #2 [Score: 0.7100]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1024 miles on a B737-900 aircraft. It arrived early by 12 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: PBX to EWX."
#      Stats: Delay=-12min | Food=5/5
#   #3 [Score: 0.7086]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1024 miles on a B737-800 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: EWX to PBX."
#      Stats: Delay=-7min | Food=5/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7819]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1024 miles on a B737-900 aircraft. It arrived early by 12 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: PBX to EWX."
#      Stats: Delay=-12min | Food=5/5
#   #2 [Score: 0.7776]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1222 miles on a B737-800 aircraft. It arrived early by 15 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: MCX to EWX."
#      Stats: Delay=-15min | Food=4/5
#   #3 [Score: 0.7773]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1958 miles on a B737-900 aircraft. It arrived early by 17 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: AUX to EWX."
#      Stats: Delay=-17min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q13: Satisfied Premier Gold members in Economy
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6722]
#      Text: "A punctual short-haul flight. The Economy journey covered 986 miles on a ERJ-175 aircraft. It was roughly on time (3 min delay). The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: CMX to IAX."
#      Stats: Delay=3min | Food=4/5
#   #2 [Score: 0.6624]
#      Text: "A punctual long-haul flight. The Economy journey covered 5417 miles on a B767-300 aircraft. It was roughly on time (10 min delay). The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: MUX to IAX."
#      Stats: Delay=10min | Food=2/5
#   #3 [Score: 0.6596]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5233 miles on a B777-200 aircraft. It arrived early by 5 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: FRX to IAX."
#      Stats: Delay=-5min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6366]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3946 miles on a B767-300 aircraft. It arrived early by 9 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: ZRX to EWX."
#      Stats: Delay=-9min | Food=5/5
#   #2 [Score: 0.6359]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3946 miles on a B767-300 aircraft. It arrived early by 9 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: EWX to ZRX."
#      Stats: Delay=-9min | Food=5/5
#   #3 [Score: 0.6345]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5062 miles on a B777-200 aircraft. It arrived early by 23 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: EZX to IAX."
#      Stats: Delay=-23min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7621]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2419 miles on a B777-300 aircraft. It arrived early by 11 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: SFX to IAX."
#      Stats: Delay=-11min | Food=4/5
#   #2 [Score: 0.7593]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1503 miles on a A320-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: AUX to SFX."
#      Stats: Delay=-9min | Food=4/5
#   #3 [Score: 0.7579]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2338 miles on a B737-MAX9 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: SFX to OGX."
#      Stats: Delay=-6min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q14: Find all flights from JNX to EWX longer than 2000 miles.
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.8476]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 0 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: EWX to JNX."
#      Stats: Delay=0min | Food=4/5
#   #2 [Score: 0.8373]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 57 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: JNX to EWX."
#      Stats: Delay=-57min | Food=5/5
#   #3 [Score: 0.8369]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 36 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: JNX to EWX."
#      Stats: Delay=-36min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7863]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7323 miles on a B787-9 aircraft. It arrived early by 33 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: DEX to EWX."
#      Stats: Delay=-33min | Food=1/5
#   #2 [Score: 0.7836]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4169 miles on a B767-300 aircraft. It arrived early by 24 minutes. The passenger (Generation: Silent, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: VCX to EWX."
#      Stats: Delay=-24min | Food=4/5
#   #3 [Score: 0.7828]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4169 miles on a B767-300 aircraft. It arrived early by 13 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: EWX to VCX."
#      Stats: Delay=-13min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8119]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 36 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: JNX to EWX."
#      Stats: Delay=-36min | Food=1/5
#   #2 [Score: 0.8106]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 22 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: JNX to EWX."
#      Stats: Delay=-22min | Food=4/5
#   #3 [Score: 0.8098]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 7989 miles on a B787-9 aircraft. It arrived early by 57 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: JNX to EWX."
#      Stats: Delay=-57min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q15: Gen X passengers flying on the A320-200
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7726]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1503 miles on a A320-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: AUX to SFX."
#      Stats: Delay=-9min | Food=4/5
#   #2 [Score: 0.7695]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1008 miles on a A320-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: EWX to MSX."
#      Stats: Delay=-9min | Food=2/5
#   #3 [Score: 0.7632]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 2419 miles on a B777-300 aircraft. It arrived early by 11 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Route: SFX to IAX."
#      Stats: Delay=-11min | Food=4/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8092]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3870 miles on a B777-300 aircraft. It arrived early by 3 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: FRX to EWX."
#      Stats: Delay=-3min | Food=1/5
#   #2 [Score: 0.8081]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1416 miles on a B737-800 aircraft. It arrived early by 26 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Route: IAX to LGX."
#      Stats: Delay=-26min | Food=2/5
#   #3 [Score: 0.8079]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3878 miles on a B767-300 aircraft. It arrived early by 28 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: GVX to EWX."
#      Stats: Delay=-28min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8366]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1190 miles on a A320-200 aircraft. It was roughly on time (3 min delay). The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: IAX to IAX."
#      Stats: Delay=3min | Food=5/5
#   #2 [Score: 0.8360]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1303 miles on a A320-200 aircraft. It arrived early by 13 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: SAX to IAX."
#      Stats: Delay=-13min | Food=4/5
#   #3 [Score: 0.8331]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1190 miles on a A320-200 aircraft. It was roughly on time (9 min delay). The passenger (Generation: Gen X, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Route: IAX to IAX."
#      Stats: Delay=9min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q16: Flights out of SEX
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6679]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 678 miles on a A319-100 aircraft. It arrived early by 7 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a poor dining experience with a rating of 2/5. Route: PHX to ORX."
#      Stats: Delay=-7min | Food=2/5
#   #2 [Score: 0.6650]
#      Text: "A highly punctual short-haul flight. The Economy journey covered 760 miles on a A319-100 aircraft. It arrived early by 31 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: CHX to ORX."
#      Stats: Delay=-31min | Food=4/5
#   #3 [Score: 0.6649]
#      Text: "A punctual short-haul flight. The Economy journey covered 651 miles on a A319-100 aircraft. It was roughly on time (8 min delay). The passenger (Generation: Gen X, Status: premier 1k) reported a poor dining experience with a rating of 2/5. Route: PHX to SFX."
#      Stats: Delay=8min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6953]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4671 miles on a B787-9 aircraft. It arrived early by 0 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a poor dining experience with a rating of 1/5. Route: LHX to DEX."
#      Stats: Delay=0min | Food=1/5
#   #2 [Score: 0.6935]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5368 miles on a B787-9 aircraft. It arrived early by 0 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: LHX to SFX."
#      Stats: Delay=0min | Food=1/5
#   #3 [Score: 0.6935]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4671 miles on a B787-9 aircraft. It arrived early by 46 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: LHX to DEX."
#      Stats: Delay=-46min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7851]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1874 miles on a B737-900 aircraft. It was roughly on time (8 min delay). The passenger (Generation: Boomer, Status: premier silver) reported a poor dining experience with a rating of 1/5. Route: SEX to IAX."
#      Stats: Delay=8min | Food=1/5
#   #2 [Score: 0.7846]
#      Text: "A punctual medium-haul flight. The Economy journey covered 1874 miles on a B737-800 aircraft. It was roughly on time (1 min delay). The passenger (Generation: Silent, Status: premier platinum) reported a poor dining experience with a rating of 2/5. Route: SEX to IAX."
#      Stats: Delay=1min | Food=2/5
#   #3 [Score: 0.7814]
#      Text: "A delayed medium-haul flight. The Economy journey covered 2306 miles on a B737-900 aircraft. It had a moderate delay of 22 minutes. The passenger (Generation: Boomer, Status: premier platinum) reported a poor dining experience with a rating of 1/5. Route: SEX to IAX."
#      Stats: Delay=22min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q17: Flights from SEX to IAX
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7684]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4834 miles on a B787-9 aircraft. It arrived early by 33 minutes. The passenger (Generation: Gen X, Status: premier platinum) reported a poor dining experience with a rating of 2/5. Route: LHX to IAX."
#      Stats: Delay=-33min | Food=2/5
#   #2 [Score: 0.7670]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5233 miles on a B777-200 aircraft. It arrived early by 5 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Route: FRX to IAX."
#      Stats: Delay=-5min | Food=5/5
#   #3 [Score: 0.7669]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 3904 miles on a B777-200 aircraft. It arrived early by 27 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: HNX to IAX."
#      Stats: Delay=-27min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7614]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It arrived early by 24 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Route: IAX to FCX."
#      Stats: Delay=-24min | Food=1/5
#   #2 [Score: 0.7579]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 5965 miles on a B787-8 aircraft. It arrived early by 12 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Route: AMX to IAX."
#      Stats: Delay=-12min | Food=2/5
#   #3 [Score: 0.7569]
#      Text: "A highly punctual long-haul flight. The Economy journey covered 4505 miles on a B787-8 aircraft. It arrived early by 22 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: IAX to FCX."
#      Stats: Delay=-22min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8148]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1117 miles on a ERJ-175 aircraft. It arrived early by 4 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Route: IAX to PIX."
#      Stats: Delay=-4min | Food=4/5
#   #2 [Score: 0.8109]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1117 miles on a A319-100 aircraft. It arrived early by 16 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Route: IAX to PIX."
#      Stats: Delay=-16min | Food=5/5
#   #3 [Score: 0.8104]
#      Text: "A highly punctual medium-haul flight. The Economy journey covered 1347 miles on a A319-100 aircraft. It arrived early by 17 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Route: IAX to SNX."
#      Stats: Delay=-17min | Food=3/5

# %% [markdown]
# ### Executive Summary
# After testing 3 embedding models against 17 distinct airline-related queries, **BAAI/bge-m3 (BGE-M3)** emerged as the superior model for this specific use case. While **MPNet** showed excellent semantic understanding of natural language concepts (like "short-haul" vs "long-haul"), **BGE-M3** was the only model capable of reliably capturing specific entities like Airport Codes (`SEX`, `JNX`) while maintaining high semantic accuracy. **MiniLM**, while likely the fastest, struggled significantly with numerical context and specific entity linking.
#
# ### Model Leaderboard
#
# | Rank | Model | Strength | Weakness | Recommendation |
# | :--- | :--- | :--- | :--- | :--- |
# | 🥇 | **BGE-M3** | **Hybrid Capabilities:** Excellent at both semantic nuances ("bad food") and exact keywords (Airport Codes). | Slower inference than MiniLM. | **Primary Choice** |
# | 🥈 | **MPNet** | **Semantic Depth:** Best understanding of length ("short-haul") and strong sentiment correlation. | **Keyword Blindness:** Completely failed to recognize specific airport codes (e.g., Q16). | Backup Choice |
# | 🥉 | **MiniLM** | **Speed:** Likely the fastest inference. | **Low Fidelity:** Confused "Medium Haul" for "Short Haul"; frequently missed negative sentiment in complex queries. | Not Recommended |
#
# ---
#
# ### Detailed Analysis by Query Category
#
# #### 1. Semantic Understanding (Sentiment & Length)
# *Tests: Q1, Q2, Q4, Q7, Q9*
#
# * **The Task:** Interpret "short flight", "long haul", "nightmare", and "terrible food".
# * **MPNet & BGE-M3 (Tie):** Both models correctly distinguished between "Short-Haul" (<1000 miles) and "Long-Haul" (>4000 miles). For Q2 ("short flight"), MPNet found flights under 900 miles, whereas MiniLM retrieved "Medium-Haul" flights over 1700 miles, failing the user intent.
# * **MiniLM (Fail):** In Q8 ("Economy... good time"), MiniLM retrieved a flight with a **2/5** food rating and called it a match. It struggled to separate the concept of "flight" from the specific sentiment "good".
#
# #### 2. Entity & Keyword Recognition (Airport Codes)
# *Tests: Q11, Q16, Q17*
#
# * **The Task:** "Flights out of SEX" (Station Code). This is the hardest task for pure dense retrievers.
# * **BGE-M3 (Winner):** It was the **only** model to successfully map "out of SEX" to `Origin: SEX` (Q16).
# * **MPNet & MiniLM (Fail):** Both models treated "SEX" and "JNX" as generic noise, retrieving flights from random airports like `PHX`, `LHX`, or `BOX`.
# * **Why this matters:** Users frequently search by airport code. Only BGE-M3 demonstrated the "Lexical + Semantic" hybrid behavior needed for this.
#
# #### 3. Complex Logic & Edge Cases
# *Tests: Q6, Q9, Q14*
#
# * **The Task:** "Food was great but flight was late" (Mixed Sentiment) and "Delay > 3 hours" (Numerical reasoning).
# * **Mixed Sentiment (Universal Fail):** All three models struggled with Q6. They prioritized the "flight" vector and either found punctual flights or bad food. This confirms that **Embeddings cannot replace Cypher** for structured filtering (e.g., `WHERE food > 4 AND delay > 0`).
# * **Numerical nuances:**
#     * In Q14 ("> 2000 miles"), **MiniLM** actually performed surprisingly well, finding the `JNX -> EWX` route.
#     * In Q9 ("Huge delay > 3 hours"), **BGE-M3** found a massive 620-minute delay, showing better sensitivity to "magnitude" words like "huge" compared to MiniLM's 85-minute result.
#
# #### 4. Demographic & Attribute Matching
# *Tests: Q4, Q5, Q12, Q15*
#
# * **The Task:** Match specific generations ("Millennial", "Boomer") or aircraft ("A320-200").
# * **Consistency:** All models performed adequately here, generally finding the correct Generation or Status when explicitly requested.
# * **Nuance:** **MPNet** seemed slightly better at pairing the demographic with the correct *sentiment* (e.g., finding an unhappy Millennial rather than just *any* Millennial).
#
# ---
#
# ### Conclusion
#
# For the Airline Graph-RAG system, **we will proceed with BGE-M3.**
#
# While MPNet offers slightly better "literary" understanding of sentiments, an airline system **must** respect airport codes and specific entities. BGE-M3's ability to act as a hybrid retriever—catching the keyword "SEX" (airport) while still understanding "severe delay"—makes it the robust choice to minimize hallucinations.
