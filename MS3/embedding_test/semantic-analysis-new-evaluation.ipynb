# %% [markdown]
# # Neo4j Semantic Search Pipeline
#
# This notebook implements a semantic search pipeline using Neo4j and Sentence Transformers. It covers:
# 1.  **Data Loading & Embedding:** Constructing semantic text from flight data and generating embeddings using three different models.
# 2.  **Index Creation:** Creating vector indices in Neo4j.
# 3.  **Search:** Executing a similarity search.

# %%
# Install necessary dependencies
# !pip install neo4j sentence-transformers python-dotenv
# Out:
# Collecting neo4j
#   Downloading neo4j-6.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.53.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Downloading neo4j-6.0.3-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 10.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, neo4j, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed neo4j-6.0.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
os.environ['NEO4J_URI'] = 'neo4j+s://dc92f3a9.databases.neo4j.io'
os.environ['NEO4J_USERNAME'] = 'neo4j'
os.environ['NEO4J_PASSWORD'] = 'UnLFJ3OvABIa5cKQ3tSx0IMqw91fDGxo8ebu13awzRY'

# %% [markdown]
# ## Part 1: Load Models & Process Data
# This step fetches journey data, creates descriptive text, generates embeddings (MiniLM, MPNet, BGE-M3), and stores them in `JourneyVector` nodes.

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os

print("Loading embedding models...")
model_minilm = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
model_mpnet = SentenceTransformer("sentence-transformers/paraphrase-mpnet-base-v2")
model_bge_m3 = SentenceTransformer("BAAI/bge-m3")

# ------------------------------
# 2. Neo4j Connection
# ------------------------------
uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
username = os.getenv('NEO4J_USERNAME', 'neo4j')
password = os.getenv('NEO4J_PASSWORD', 'password')

driver = GraphDatabase.driver(uri, auth=(username, password))

# ------------------------------
# Helper: Semantic Text Builder
# ------------------------------
def build_semantic_text(record):
    """
    Constructs a qualitative narrative using the provided airline metrics.
    Now optimized for 'Route' phrasing and 'Record Lookup'.
    """
    # --- Delay Context ---
    delay = record['arrival_delay_minutes']
    if delay <= 0:
        delay_desc = f"arrived early by {abs(delay)} minutes"
        punctuality = "highly punctual"
    elif delay <= 15:
        delay_desc = f"was roughly on time ({delay} min delay)"
        punctuality = "punctual"
    elif delay <= 60:
        delay_desc = f"had a moderate delay of {delay} minutes"
        punctuality = "delayed"
    else:
        delay_desc = f"suffered a severe delay of {delay} minutes"
        punctuality = "severely delayed"

    # --- Food Context ---
    score = record['food_satisfaction_score']
    if score <= 2:
        food_desc = "poor dining experience"
    elif score == 3:
        food_desc = "average dining experience"
    else:
        food_desc = "excellent dining experience"

    # --- Distance Context ---
    miles = record['actual_flown_miles']
    if miles < 1000:
        haul = "short-haul"
    elif miles < 4000:
        haul = "medium-haul"
    else:
        haul = "long-haul"

    
    text = (
        f"A {punctuality} {haul} flight operating out of {record['origin']}. "
        f"The flight departs from {record['origin']} and arrives at {record['destination']}. "
        f"The {record['passenger_class']} journey covered {miles} miles on a {record['fleet_type_description']} aircraft. "
        f"It {delay_desc}. "
        f"The passenger (Generation: {record['generation']}, Status: {record['loyalty_program_level']}) "
        f"reported a {food_desc} with a rating of {score}/5. "
        f"Passenger record locator is {record['record_locator']} and Feedback ID is {record['feedback_ID']}."
    )
    return text

# ------------------------------
# 3. Processing Pipeline
# ------------------------------
def process(tx):
    print("Fetching journey data...")
    result = tx.run("""
        MATCH (p:Passenger)-[:TOOK]->(j:Journey)-[:ON]->(f:Flight)
        MATCH (f)-[:DEPARTS_FROM]->(dep:Airport)
        MATCH (f)-[:ARRIVES_AT]->(arr:Airport)
        RETURN
            j.feedback_ID AS feedback_ID,
            p.record_locator AS record_locator,
            p.generation AS generation,
            p.loyalty_program_level AS loyalty_program_level,
            j.food_satisfaction_score AS food_satisfaction_score,
            j.arrival_delay_minutes AS arrival_delay_minutes,
            j.actual_flown_miles AS actual_flown_miles,
            j.passenger_class AS passenger_class,
            f.fleet_type_description AS fleet_type_description,
            dep.station_code AS origin,
            arr.station_code AS destination
    """)
    
    records = list(result)
    print(f"Found {len(records)} journeys to embed.")

    for i, row in enumerate(records):
        # 1. Build rich text with  route/ID phrasing
        text = build_semantic_text(row)

        # 2. Generate embeddings
        emb_minilm = model_minilm.encode(text).tolist()
        emb_mpnet = model_mpnet.encode(text).tolist()
        emb_bge_m3 = model_bge_m3.encode(text).tolist()

        # 3. Store in SEPARATE Node (:JourneyVector)
        tx.run("""
            MATCH (j:Journey {feedback_ID: $fid})
            
            MERGE (jv:JourneyVector {id: $fid + '_vec'})
            ON CREATE SET 
                jv.text = $text,
                jv.record_locator = $locator,  
                jv.feedback_id = $fid,         
                jv.minilm_embedding = $e1,
                jv.mpnet_embedding = $e2,
                jv.bgem3_embedding = $e3
            ON MATCH SET
                jv.text = $text,
                jv.record_locator = $locator,
                jv.feedback_id = $fid,
                jv.minilm_embedding = $e1,
                jv.mpnet_embedding = $e2,
                jv.bgem3_embedding = $e3
            
            MERGE (j)-[:HAS_VECTOR]->(jv)
        """, 
        fid=row['feedback_ID'],
        locator=row['record_locator'],
        text=text,
        e1=emb_minilm, 
        e2=emb_mpnet, 
        e3=emb_bge_m3)

        if i % 50 == 0:
            print(f"Processed {i}/{len(records)}...")

with driver.session() as session:
    session.execute_write(process)

print("Done! Vectors stored in 'JourneyVector' nodes.")

# %% [markdown]
# ## Part 2: Create Indices
# Creates Vector Indices in Neo4j for the three different embedding models.

# %%
from neo4j import GraphDatabase
import os

uri = os.getenv('NEO4J_URI')
username = os.getenv('NEO4J_USERNAME')
password = os.getenv('NEO4J_PASSWORD')

driver = GraphDatabase.driver(uri, auth=(username, password))

def create_indices():
    with driver.session() as session:
        print("Creating indices on :JourneyVector...")

        # 1. MiniLM
        session.run("""
            CREATE VECTOR INDEX minilm_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.minilm_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 384, `vector.similarity_function`: 'cosine'}}
        """)
        
        # 2. MPNet
        session.run("""
            CREATE VECTOR INDEX mpnet_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.mpnet_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 768, `vector.similarity_function`: 'cosine'}}
        """)

        # 3. BGE-M3
        session.run("""
            CREATE VECTOR INDEX bgem3_vec_index IF NOT EXISTS
            FOR (n:JourneyVector) ON (n.bgem3_embedding)
            OPTIONS {indexConfig: {`vector.dimensions`: 1024, `vector.similarity_function`: 'cosine'}}
        """)

        print("Indices created successfully.")

if __name__ == "__main__":
    create_indices()

# %% [markdown]
# ## Part 3: Semantic Search Test
# Performs a test search using the MiniLM model.

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os 
from dotenv import load_dotenv

load_dotenv()

# We'll test with MiniLM for speed
model = SentenceTransformer("BAAI/bge-m3")

uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
username = os.getenv('NEO4J_USERNAME', 'neo4j')
password = os.getenv('NEO4J_PASSWORD', 'password')
driver = GraphDatabase.driver(uri, auth=(username, password))

def search(query, top_k=3):
    embedding = model.encode(query).tolist()
    
    cypher = """
    CALL db.index.vector.queryNodes('bgem3_vec_index', $k, $vec)
    YIELD node, score
    
    MATCH (j:Journey)-[:HAS_VECTOR]->(node)
    MATCH (p:Passenger)-[:TOOK]->(j)
    
    RETURN 
        score,
        node.text AS semantic_text,
        j.feedback_ID AS feedback_id,
        j.arrival_delay_minutes AS actual_delay,
        j.food_satisfaction_score AS actual_food
    """
    
    with driver.session() as session:
        result = session.run(cypher, k=top_k, vec=embedding)
        return [dict(r) for r in result]

if __name__ == "__main__":
    print("--- Testing Semantic Search ---")
    q = "big delays and bad food"
    print(f"Query: '{q}'")
    
    results = search(q)
    for r in results:
        print(f"\nScore: {r['score']:.4f}")
        print(f"Text: {r['semantic_text']}")
        print(f"DB Check -> Delay: {r['actual_delay']}, Food: {r['actual_food']}")

# %% [markdown]
# ## Comparitive Analysis

# %%
from neo4j import GraphDatabase
from sentence_transformers import SentenceTransformer
import os
from dotenv import load_dotenv

load_dotenv()

# ---------------------------------------------------------
# 1. SETUP: Load All 3 Models
# ---------------------------------------------------------
print("Loading models... (This might take a minute)")
models = {
    "minilm": {
        "model": SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2"),
        "index": "minilm_vec_index"
    },
    "mpnet": {
        "model": SentenceTransformer("sentence-transformers/paraphrase-mpnet-base-v2"),
        "index": "mpnet_vec_index"
    },
    "bge-m3": {
        "model": SentenceTransformer("BAAI/bge-m3"),
        "index": "bgem3_vec_index"
    }
}

uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
username = os.getenv('NEO4J_USERNAME', 'neo4j')
password = os.getenv('NEO4J_PASSWORD', 'password')
driver = GraphDatabase.driver(uri, auth=(username, password))


QUESTIONS = [
    "Q1: flights with severe delays and terrible food",
    "Q2: excellent dining experience on a short flight",
    "Q3: unhappy passengers on Boeing aircraft",
    "Q4: Millennial generation complaining about delays",
    "Q5: Premier Gold members with poor satisfaction",
    "Q6: The food was great but the flight was late",
    "Q7: long haul flights that arrived early",
    "Q8: Economy class passengers who had a good time",
    "Q9: nightmare journey with huge delay over 3 hours",
    "Q10: smooth trip with no issues",
    "Q11: Show me the delay for a flight out of JNX", 
    "Q12: Boomers who had excellent food", 
    "Q13: Satisfied Premier Gold members in Economy", 
    "Q14: Find all flights from JNX to EWX longer than 2000 miles.", 
    "Q15: Gen X passengers flying on the A320-200", 
    "Q16: Flights out of SEX", 
    "Q17: Flights from SEX to IAX", 
    "Q18: Pull up the record locator EPXXW8.", 
    "Q18: Pull up the feedback ID F_18."
    
]

# ---------------------------------------------------------
# 3. SEARCH LOGIC
# ---------------------------------------------------------
def search(query, model_key, top_k=3):
    model_obj = models[model_key]["model"]
    index_name = models[model_key]["index"]
    
    embedding = model_obj.encode(query).tolist()
    
    cypher = f"""
    CALL db.index.vector.queryNodes('{index_name}', $k, $vec)
    YIELD node, score
    
    MATCH (j:Journey)-[:HAS_VECTOR]->(node)
    
    RETURN 
        score,
        node.text AS semantic_text,
        j.arrival_delay_minutes AS actual_delay,
        j.food_satisfaction_score AS actual_food
    """
    
    with driver.session() as session:
        result = session.run(cypher, k=top_k, vec=embedding)
        return [dict(r) for r in result]

# ---------------------------------------------------------
# 4. EXECUTION LOOP
# ---------------------------------------------------------
if __name__ == "__main__":
    print("\n=== STARTING 3-MODEL COMPARISON (Top 3 Results) ===\n")

    for q in QUESTIONS:
        print(f"_"*80)
        print(f"QUERY: {q}")
        print(f"_"*80)
        
        for model_name in ["minilm", "mpnet", "bge-m3"]:
            print(f"\n--- MODEL: {model_name.upper()} ---")
            try:
                results = search(q, model_name, top_k=3)
                
                if not results:
                    print("  No results found.")
                    continue

                for i, r in enumerate(results):
                    print(f"  #{i+1} [Score: {r['score']:.4f}]")
                    # Truncate text to keep output clean
                    clean_text = r['semantic_text']
                    print(f"     Text: \"{clean_text}\"")
                    print(f"     Stats: Delay={r['actual_delay']}min | Food={r['actual_food']}/5")
                
            except Exception as e:
                print(f"  Error: {e}")
        
        print("\n")
# Out:
# Loading models... (This might take a minute)
#
# === STARTING 3-MODEL COMPARISON (Top 3 Results) ===
#
# ________________________________________________________________________________
# QUERY: Q1: flights with severe delays and terrible food
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7518]
#      Text: "A severely delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at IAX. The Economy journey covered 1400 miles on a B737-MAX8 aircraft. It suffered a severe delay of 177 minutes. The passenger (Generation: Millennial, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is M4XXTP and Feedback ID is F_3."
#      Stats: Delay=177min | Food=1/5
#   #2 [Score: 0.7510]
#      Text: "A severely delayed short-haul flight operating out of MIX. The flight departs from MIX and arrives at IAX. The Economy journey covered 717 miles on a B737-800 aircraft. It suffered a severe delay of 234 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is LZXXJ1 and Feedback ID is F_1273."
#      Stats: Delay=234min | Food=2/5
#   #3 [Score: 0.7496]
#      Text: "A severely delayed medium-haul flight operating out of LAX. The flight departs from LAX and arrives at ORX. The Economy journey covered 1745 miles on a B757-300 aircraft. It suffered a severe delay of 162 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is A5XX26 and Feedback ID is F_1234."
#      Stats: Delay=162min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8595]
#      Text: "A severely delayed long-haul flight operating out of IAX. The flight departs from IAX and arrives at FRX. The Economy journey covered 4082 miles on a B777-200 aircraft. It suffered a severe delay of 77 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is NFXXDE and Feedback ID is F_1325."
#      Stats: Delay=77min | Food=2/5
#   #2 [Score: 0.8564]
#      Text: "A severely delayed long-haul flight operating out of IAX. The flight departs from IAX and arrives at FRX. The Economy journey covered 5233 miles on a B777-200 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is MMXXRQ and Feedback ID is F_903."
#      Stats: Delay=62min | Food=1/5
#   #3 [Score: 0.8552]
#      Text: "A severely delayed long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is N9XX0Q and Feedback ID is F_375."
#      Stats: Delay=62min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8183]
#      Text: "A severely delayed long-haul flight operating out of SFX. The flight departs from SFX and arrives at CDX. The Economy journey covered 5583 miles on a B777-200 aircraft. It suffered a severe delay of 111 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is K2XXSS and Feedback ID is F_315."
#      Stats: Delay=111min | Food=1/5
#   #2 [Score: 0.8179]
#      Text: "A severely delayed long-haul flight operating out of IAX. The flight departs from IAX and arrives at FRX. The Economy journey covered 5233 miles on a B777-200 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is MMXXRQ and Feedback ID is F_903."
#      Stats: Delay=62min | Food=1/5
#   #3 [Score: 0.8179]
#      Text: "A severely delayed long-haul flight operating out of MUX. The flight departs from MUX and arrives at SFX. The Economy journey covered 5889 miles on a B777-300 aircraft. It suffered a severe delay of 73 minutes. The passenger (Generation: Gen X, Status: premier platinum) reported a poor dining experience with a rating of 1/5. Passenger record locator is NVXXQF and Feedback ID is F_2728."
#      Stats: Delay=73min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q2: excellent dining experience on a short flight
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7461]
#      Text: "A highly punctual short-haul flight operating out of MIX. The flight departs from MIX and arrives at IAX. The Economy journey covered 921 miles on a B737-900 aircraft. It arrived early by 14 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is E1XXTG and Feedback ID is F_2523."
#      Stats: Delay=-14min | Food=5/5
#   #2 [Score: 0.7456]
#      Text: "A punctual medium-haul flight operating out of BOX. The flight departs from BOX and arrives at IAX. The Economy journey covered 2222 miles on a B737-700 aircraft. It was roughly on time (9 min delay). The passenger (Generation: Millennial, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Passenger record locator is N4XX3L and Feedback ID is F_445."
#      Stats: Delay=9min | Food=5/5
#   #3 [Score: 0.7450]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 19 minutes. The passenger (Generation: Silent, Status: premier silver) reported a excellent dining experience with a rating of 4/5. Passenger record locator is M1XX29 and Feedback ID is F_573."
#      Stats: Delay=-19min | Food=4/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8312]
#      Text: "A highly punctual short-haul flight operating out of MYX. The flight departs from MYX and arrives at EWX. The Economy journey covered 550 miles on a A320-200 aircraft. It arrived early by 19 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is A0XX96 and Feedback ID is F_2798."
#      Stats: Delay=-19min | Food=5/5
#   #2 [Score: 0.8309]
#      Text: "A highly punctual short-haul flight operating out of BWX. The flight departs from BWX and arrives at ORX. The Economy journey covered 621 miles on a A320-200 aircraft. It arrived early by 17 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is J4XX4C and Feedback ID is F_2828."
#      Stats: Delay=-17min | Food=5/5
#   #3 [Score: 0.8296]
#      Text: "A highly punctual short-haul flight operating out of IAX. The flight departs from IAX and arrives at TPX. The Economy journey covered 787 miles on a A320-200 aircraft. It arrived early by 2 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is NLXXGE and Feedback ID is F_726."
#      Stats: Delay=-2min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8337]
#      Text: "A highly punctual short-haul flight operating out of PHX. The flight departs from PHX and arrives at DEX. The Economy journey covered 602 miles on a A320-200 aircraft. It arrived early by 2 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is E9XXJN and Feedback ID is F_1496."
#      Stats: Delay=-2min | Food=1/5
#   #2 [Score: 0.8330]
#      Text: "A highly punctual short-haul flight operating out of CHX. The flight departs from CHX and arrives at EWX. The Economy journey covered 628 miles on a ERJ-175 aircraft. It arrived early by 6 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is DTXXXE and Feedback ID is F_1026."
#      Stats: Delay=-6min | Food=4/5
#   #3 [Score: 0.8324]
#      Text: "A highly punctual short-haul flight operating out of PHX. The flight departs from PHX and arrives at DEX. The Economy journey covered 602 miles on a A320-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is K3XXFL and Feedback ID is F_2272."
#      Stats: Delay=-9min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q3: unhappy passengers on Boeing aircraft
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7395]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 2 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Passenger record locator is DQXXYJ and Feedback ID is F_1119."
#      Stats: Delay=-2min | Food=2/5
#   #2 [Score: 0.7367]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 1874 miles on a B737-800 aircraft. It arrived early by 14 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is BSXX5B and Feedback ID is F_592."
#      Stats: Delay=-14min | Food=3/5
#   #3 [Score: 0.7318]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at EWX. The Economy journey covered 2401 miles on a B737-900 aircraft. It arrived early by 8 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is GMXXNN and Feedback ID is F_385."
#      Stats: Delay=-8min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8101]
#      Text: "A severely delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at IAX. The Economy journey covered 1400 miles on a B767-300 aircraft. It suffered a severe delay of 104 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a poor dining experience with a rating of 2/5. Passenger record locator is MGXX6H and Feedback ID is F_76."
#      Stats: Delay=104min | Food=2/5
#   #2 [Score: 0.8096]
#      Text: "A severely delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at SNX. The Economy journey covered 3096 miles on a B757-200 aircraft. It suffered a severe delay of 124 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is NZXXC7 and Feedback ID is F_1700."
#      Stats: Delay=124min | Food=2/5
#   #3 [Score: 0.8081]
#      Text: "A severely delayed medium-haul flight operating out of MSX. The flight departs from MSX and arrives at EWX. The Economy journey covered 1008 miles on a A319-100 aircraft. It suffered a severe delay of 90 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is AJXXR5 and Feedback ID is F_951."
#      Stats: Delay=90min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7843]
#      Text: "A delayed medium-haul flight operating out of AUX. The flight departs from AUX and arrives at EWX. The Economy journey covered 1958 miles on a B737-900 aircraft. It had a moderate delay of 37 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is B4XXPC and Feedback ID is F_1817."
#      Stats: Delay=37min | Food=2/5
#   #2 [Score: 0.7832]
#      Text: "A delayed medium-haul flight operating out of BQX. The flight departs from BQX and arrives at EWX. The Economy journey covered 1585 miles on a B737-900 aircraft. It had a moderate delay of 28 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is BDXX92 and Feedback ID is F_906."
#      Stats: Delay=28min | Food=2/5
#   #3 [Score: 0.7804]
#      Text: "A delayed medium-haul flight operating out of ORX. The flight departs from ORX and arrives at AUX. The Economy journey covered 2298 miles on a B737-900 aircraft. It had a moderate delay of 45 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is LEXX9V and Feedback ID is F_1949."
#      Stats: Delay=45min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q4: Millennial generation complaining about delays
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7041]
#      Text: "A delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at DEX. The Economy journey covered 1605 miles on a B737-900 aircraft. It had a moderate delay of 49 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is P0XXKR and Feedback ID is F_1128."
#      Stats: Delay=49min | Food=1/5
#   #2 [Score: 0.7040]
#      Text: "A severely delayed short-haul flight operating out of EWX. The flight departs from EWX and arrives at BOX. The Economy journey covered 200 miles on a B737-800 aircraft. It suffered a severe delay of 85 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is M2XXNP and Feedback ID is F_982."
#      Stats: Delay=85min | Food=1/5
#   #3 [Score: 0.6988]
#      Text: "A delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at DEX. The Economy journey covered 1605 miles on a B737-900 aircraft. It had a moderate delay of 42 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is NQXX2C and Feedback ID is F_368."
#      Stats: Delay=42min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7042]
#      Text: "A severely delayed long-haul flight operating out of IAX. The flight departs from IAX and arrives at FRX. The Economy journey covered 4082 miles on a B777-200 aircraft. It suffered a severe delay of 77 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is NFXXDE and Feedback ID is F_1325."
#      Stats: Delay=77min | Food=2/5
#   #2 [Score: 0.7039]
#      Text: "A severely delayed long-haul flight operating out of FCX. The flight departs from FCX and arrives at EWX. The Economy journey covered 4292 miles on a B777-200 aircraft. It suffered a severe delay of 118 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is ECXXM5 and Feedback ID is F_1058."
#      Stats: Delay=118min | Food=3/5
#   #3 [Score: 0.7036]
#      Text: "A severely delayed medium-haul flight operating out of BGX. The flight departs from BGX and arrives at EWX. The Economy journey covered 3501 miles on a B757-200 aircraft. It suffered a severe delay of 172 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is IEXXNY and Feedback ID is F_1818."
#      Stats: Delay=172min | Food=3/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7767]
#      Text: "A delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at FRX. The Economy journey covered 3870 miles on a B777-300 aircraft. It had a moderate delay of 17 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is CPXXFP and Feedback ID is F_166."
#      Stats: Delay=17min | Food=1/5
#   #2 [Score: 0.7763]
#      Text: "A delayed medium-haul flight operating out of SNX. The flight departs from SNX and arrives at EWX. The Economy journey covered 2433 miles on a B737-700 aircraft. It had a moderate delay of 22 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is GMXX7L and Feedback ID is F_1216."
#      Stats: Delay=22min | Food=2/5
#   #3 [Score: 0.7762]
#      Text: "A delayed medium-haul flight operating out of PHX. The flight departs from PHX and arrives at ORX. The Economy journey covered 1440 miles on a B737-900 aircraft. It had a moderate delay of 48 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is BZXX86 and Feedback ID is F_2925."
#      Stats: Delay=48min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q5: Premier Gold members with poor satisfaction
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6200]
#      Text: "A highly punctual long-haul flight operating out of ATX. The flight departs from ATX and arrives at EWX. The Economy journey covered 4948 miles on a B787-10 aircraft. It arrived early by 15 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is B5XXJE and Feedback ID is F_774."
#      Stats: Delay=-15min | Food=1/5
#   #2 [Score: 0.6166]
#      Text: "A punctual long-haul flight operating out of MUX. The flight departs from MUX and arrives at IAX. The Economy journey covered 5417 miles on a B767-300 aircraft. It was roughly on time (10 min delay). The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 2/5. Passenger record locator is FRXXHH and Feedback ID is F_2580."
#      Stats: Delay=10min | Food=2/5
#   #3 [Score: 0.6156]
#      Text: "A highly punctual long-haul flight operating out of FRX. The flight departs from FRX and arrives at IAX. The Economy journey covered 5233 miles on a B777-200 aircraft. It arrived early by 5 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 5/5. Passenger record locator is PLXXDM and Feedback ID is F_2749."
#      Stats: Delay=-5min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6623]
#      Text: "A highly punctual medium-haul flight operating out of GVX. The flight departs from GVX and arrives at EWX. The Economy journey covered 3878 miles on a B767-300 aircraft. It arrived early by 28 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a poor dining experience with a rating of 2/5. Passenger record locator is B9XX45 and Feedback ID is F_2533."
#      Stats: Delay=-28min | Food=2/5
#   #2 [Score: 0.6592]
#      Text: "A highly punctual medium-haul flight operating out of BGX. The flight departs from BGX and arrives at EWX. The Economy journey covered 3501 miles on a B757-200 aircraft. It arrived early by 19 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a poor dining experience with a rating of 1/5. Passenger record locator is PJXX2J and Feedback ID is F_245."
#      Stats: Delay=-19min | Food=1/5
#   #3 [Score: 0.6581]
#      Text: "A highly punctual long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It arrived early by 12 minutes. The passenger (Generation: Boomer, Status: premier platinum) reported a poor dining experience with a rating of 1/5. Passenger record locator is B8XX4W and Feedback ID is F_2659."
#      Stats: Delay=-12min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7369]
#      Text: "A delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at LIX. The Economy journey covered 3385 miles on a B787-10 aircraft. It had a moderate delay of 41 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is P8XXK1 and Feedback ID is F_2134."
#      Stats: Delay=41min | Food=1/5
#   #2 [Score: 0.7363]
#      Text: "A delayed short-haul flight operating out of BOX. The flight departs from BOX and arrives at ORX. The Economy journey covered 867 miles on a A319-100 aircraft. It had a moderate delay of 16 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Passenger record locator is AFXXPC and Feedback ID is F_2219."
#      Stats: Delay=16min | Food=2/5
#   #3 [Score: 0.7337]
#      Text: "A delayed short-haul flight operating out of LAX. The flight departs from LAX and arrives at SFX. The Economy journey covered 337 miles on a B757-200 aircraft. It had a moderate delay of 33 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is CJXXTH and Feedback ID is F_983."
#      Stats: Delay=33min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q6: The food was great but the flight was late
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7300]
#      Text: "A highly punctual medium-haul flight operating out of BOX. The flight departs from BOX and arrives at LAX. The Economy journey covered 2611 miles on a B737-900 aircraft. It arrived early by 8 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is G6XX3M and Feedback ID is F_1641."
#      Stats: Delay=-8min | Food=2/5
#   #2 [Score: 0.7287]
#      Text: "A highly punctual medium-haul flight operating out of BOX. The flight departs from BOX and arrives at LAX. The Economy journey covered 2611 miles on a B737-MAX9 aircraft. It arrived early by 32 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Passenger record locator is E8XX3P and Feedback ID is F_2948."
#      Stats: Delay=-32min | Food=5/5
#   #3 [Score: 0.7233]
#      Text: "A highly punctual medium-haul flight operating out of BOX. The flight departs from BOX and arrives at LAX. The Economy journey covered 2611 miles on a B737-MAX9 aircraft. It arrived early by 29 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is GJXXBX and Feedback ID is F_2690."
#      Stats: Delay=-29min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8351]
#      Text: "A punctual long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It was roughly on time (13 min delay). The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is ELXX9Q and Feedback ID is F_523."
#      Stats: Delay=13min | Food=3/5
#   #2 [Score: 0.8319]
#      Text: "A punctual long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It was roughly on time (7 min delay). The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is ATXXPG and Feedback ID is F_1627."
#      Stats: Delay=7min | Food=3/5
#   #3 [Score: 0.8317]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 42 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is H8XX2X and Feedback ID is F_710."
#      Stats: Delay=42min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8346]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 21 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is DQXXR8 and Feedback ID is F_2907."
#      Stats: Delay=21min | Food=5/5
#   #2 [Score: 0.8320]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 42 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is C7XX8C and Feedback ID is F_941."
#      Stats: Delay=42min | Food=2/5
#   #3 [Score: 0.8315]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 42 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is FYXXQH and Feedback ID is F_96."
#      Stats: Delay=42min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q7: long haul flights that arrived early
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.8043]
#      Text: "A highly punctual medium-haul flight operating out of BOX. The flight departs from BOX and arrives at LAX. The Economy journey covered 2611 miles on a B737-MAX9 aircraft. It arrived early by 29 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is GJXXBX and Feedback ID is F_2690."
#      Stats: Delay=-29min | Food=5/5
#   #2 [Score: 0.8041]
#      Text: "A highly punctual medium-haul flight operating out of BWX. The flight departs from BWX and arrives at LAX. The Economy journey covered 2329 miles on a B737-900 aircraft. It arrived early by 16 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is BYXXS3 and Feedback ID is F_2882."
#      Stats: Delay=-16min | Food=2/5
#   #3 [Score: 0.8021]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at HNX. The Economy journey covered 2556 miles on a B737-800 aircraft. It arrived early by 31 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is MNXX1L and Feedback ID is F_2583."
#      Stats: Delay=-31min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8508]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 21 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is DQXXR8 and Feedback ID is F_2907."
#      Stats: Delay=21min | Food=5/5
#   #2 [Score: 0.8494]
#      Text: "A delayed medium-haul flight operating out of BQX. The flight departs from BQX and arrives at EWX. The Economy journey covered 1585 miles on a B737-900 aircraft. It had a moderate delay of 28 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is BDXX92 and Feedback ID is F_906."
#      Stats: Delay=28min | Food=2/5
#   #3 [Score: 0.8461]
#      Text: "A delayed long-haul flight operating out of SIX. The flight departs from SIX and arrives at SFX. The Economy journey covered 8440 miles on a B787-9 aircraft. It had a moderate delay of 30 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is LYXXY0 and Feedback ID is F_461."
#      Stats: Delay=30min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8066]
#      Text: "A highly punctual long-haul flight operating out of LHX. The flight departs from LHX and arrives at DEX. The Economy journey covered 4671 miles on a B787-9 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is HQXXRE and Feedback ID is F_1179."
#      Stats: Delay=-7min | Food=5/5
#   #2 [Score: 0.8064]
#      Text: "A highly punctual long-haul flight operating out of LAX. The flight departs from LAX and arrives at SYX. The Economy journey covered 7487 miles on a B787-9 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is G1XX9G and Feedback ID is F_1779."
#      Stats: Delay=-6min | Food=4/5
#   #3 [Score: 0.8058]
#      Text: "A highly punctual long-haul flight operating out of LHX. The flight departs from LHX and arrives at DEX. The Economy journey covered 4671 miles on a B787-9 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is IQXXF6 and Feedback ID is F_594."
#      Stats: Delay=-7min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q8: Economy class passengers who had a good time
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7425]
#      Text: "A highly punctual medium-haul flight operating out of SJX. The flight departs from SJX and arrives at IAX. The Economy journey covered 2007 miles on a B737-900 aircraft. It arrived early by 8 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is GJXXNN and Feedback ID is F_815."
#      Stats: Delay=-8min | Food=4/5
#   #2 [Score: 0.7418]
#      Text: "A highly punctual medium-haul flight operating out of IAX. The flight departs from IAX and arrives at SJX. The Economy journey covered 2007 miles on a B737-900 aircraft. It arrived early by 18 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is NTXX1B and Feedback ID is F_1745."
#      Stats: Delay=-18min | Food=4/5
#   #3 [Score: 0.7412]
#      Text: "A highly punctual medium-haul flight operating out of SJX. The flight departs from SJX and arrives at IAX. The Economy journey covered 2007 miles on a B737-900 aircraft. It arrived early by 31 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is O5XXN8 and Feedback ID is F_295."
#      Stats: Delay=-31min | Food=3/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7792]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at IAX. The Economy journey covered 1222 miles on a B737-MAX9 aircraft. It arrived early by 4 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is JQXXCN and Feedback ID is F_628."
#      Stats: Delay=-4min | Food=4/5
#   #2 [Score: 0.7792]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at IAX. The Economy journey covered 1222 miles on a B737-900 aircraft. It arrived early by 15 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is NBXXTQ and Feedback ID is F_556."
#      Stats: Delay=-15min | Food=4/5
#   #3 [Score: 0.7789]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at BWX. The Economy journey covered 2329 miles on a B737-900 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is G1XX46 and Feedback ID is F_2876."
#      Stats: Delay=-6min | Food=3/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8263]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at EWX. The Economy journey covered 2227 miles on a B737-MAX8 aircraft. It arrived early by 8 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is MRXXN4 and Feedback ID is F_831."
#      Stats: Delay=-8min | Food=5/5
#   #2 [Score: 0.8232]
#      Text: "A highly punctual medium-haul flight operating out of AUX. The flight departs from AUX and arrives at EWX. The Economy journey covered 1504 miles on a B737-MAX8 aircraft. It arrived early by 3 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is BZXXES and Feedback ID is F_22."
#      Stats: Delay=-3min | Food=5/5
#   #3 [Score: 0.8221]
#      Text: "A highly punctual medium-haul flight operating out of LAX. The flight departs from LAX and arrives at EWX. The Economy journey covered 2227 miles on a B737-MAX8 aircraft. It arrived early by 1 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a excellent dining experience with a rating of 4/5. Passenger record locator is PZXX01 and Feedback ID is F_2704."
#      Stats: Delay=-1min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q9: nightmare journey with huge delay over 3 hours
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7522]
#      Text: "A severely delayed short-haul flight operating out of EWX. The flight departs from EWX and arrives at BOX. The Economy journey covered 200 miles on a B737-800 aircraft. It suffered a severe delay of 85 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is M2XXNP and Feedback ID is F_982."
#      Stats: Delay=85min | Food=1/5
#   #2 [Score: 0.7430]
#      Text: "A delayed short-haul flight operating out of EWX. The flight departs from EWX and arrives at TPX. The Economy journey covered 998 miles on a B737-900 aircraft. It had a moderate delay of 35 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is B1XXB4 and Feedback ID is F_2029."
#      Stats: Delay=35min | Food=5/5
#   #3 [Score: 0.7427]
#      Text: "A severely delayed short-haul flight operating out of EWX. The flight departs from EWX and arrives at CMX. The Economy journey covered 462 miles on a B737-800 aircraft. It suffered a severe delay of 172 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is BFXXGZ and Feedback ID is F_1644."
#      Stats: Delay=172min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8043]
#      Text: "A severely delayed long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is N9XX0Q and Feedback ID is F_375."
#      Stats: Delay=62min | Food=1/5
#   #2 [Score: 0.8013]
#      Text: "A severely delayed long-haul flight operating out of FCX. The flight departs from FCX and arrives at EWX. The Economy journey covered 4292 miles on a B777-200 aircraft. It suffered a severe delay of 118 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is ECXXM5 and Feedback ID is F_1058."
#      Stats: Delay=118min | Food=3/5
#   #3 [Score: 0.8013]
#      Text: "A severely delayed long-haul flight operating out of EWX. The flight departs from EWX and arrives at DEX. The Economy journey covered 7323 miles on a B787-9 aircraft. It suffered a severe delay of 68 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is ICXX5M and Feedback ID is F_1520."
#      Stats: Delay=68min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8164]
#      Text: "A severely delayed long-haul flight operating out of SFX. The flight departs from SFX and arrives at SIX. The Economy journey covered 8440 miles on a B787-9 aircraft. It suffered a severe delay of 63 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is OTXX63 and Feedback ID is F_434."
#      Stats: Delay=63min | Food=1/5
#   #2 [Score: 0.8116]
#      Text: "A severely delayed long-haul flight operating out of SFX. The flight departs from SFX and arrives at SIX. The Economy journey covered 8440 miles on a B787-9 aircraft. It suffered a severe delay of 620 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is LSXXPM and Feedback ID is F_2651."
#      Stats: Delay=620min | Food=4/5
#   #3 [Score: 0.8108]
#      Text: "A severely delayed long-haul flight operating out of SFX. The flight departs from SFX and arrives at SYX. The Economy journey covered 7417 miles on a B777-300 aircraft. It suffered a severe delay of 61 minutes. The passenger (Generation: Boomer, Status: premier platinum) reported a poor dining experience with a rating of 2/5. Passenger record locator is DSXXNP and Feedback ID is F_1390."
#      Stats: Delay=61min | Food=2/5
#
#
# ________________________________________________________________________________
# QUERY: Q10: smooth trip with no issues
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6598]
#      Text: "A severely delayed long-haul flight operating out of LHX. The flight departs from LHX and arrives at SFX. The Economy journey covered 5368 miles on a B777-200 aircraft. It suffered a severe delay of 95 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is I7XX6Y and Feedback ID is F_2335."
#      Stats: Delay=95min | Food=2/5
#   #2 [Score: 0.6576]
#      Text: "A delayed long-haul flight operating out of LHX. The flight departs from LHX and arrives at SFX. The Economy journey covered 5368 miles on a B787-9 aircraft. It had a moderate delay of 21 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is GTXXM9 and Feedback ID is F_185."
#      Stats: Delay=21min | Food=1/5
#   #3 [Score: 0.6567]
#      Text: "A delayed long-haul flight operating out of LHX. The flight departs from LHX and arrives at SFX. The Economy journey covered 5368 miles on a B787-9 aircraft. It had a moderate delay of 35 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is HNXXVG and Feedback ID is F_1447."
#      Stats: Delay=35min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.7495]
#      Text: "A highly punctual short-haul flight operating out of PNX. The flight departs from PNX and arrives at IAX. The Economy journey covered 489 miles on a A319-100 aircraft. It arrived early by 8 minutes. The passenger (Generation: Gen Z, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is IXXX5B and Feedback ID is F_1977."
#      Stats: Delay=-8min | Food=5/5
#   #2 [Score: 0.7494]
#      Text: "A highly punctual long-haul flight operating out of ZRX. The flight departs from ZRX and arrives at IAX. The Economy journey covered 4158 miles on a B767-300 aircraft. It arrived early by 7 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is LHXXV4 and Feedback ID is F_945."
#      Stats: Delay=-7min | Food=4/5
#   #3 [Score: 0.7482]
#      Text: "A punctual long-haul flight operating out of ZRX. The flight departs from ZRX and arrives at SFX. The Economy journey covered 5841 miles on a B777-200 aircraft. It was roughly on time (12 min delay). The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is M0XX6B and Feedback ID is F_1875."
#      Stats: Delay=12min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7751]
#      Text: "A highly punctual long-haul flight operating out of MUX. The flight departs from MUX and arrives at ORX. The Economy journey covered 4530 miles on a B787-10 aircraft. It arrived early by 10 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is G0XXSE and Feedback ID is F_359."
#      Stats: Delay=-10min | Food=5/5
#   #2 [Score: 0.7729]
#      Text: "A punctual long-haul flight operating out of ORX. The flight departs from ORX and arrives at BRX. The Economy journey covered 4160 miles on a B787-10 aircraft. It was roughly on time (4 min delay). The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is FQXX3B and Feedback ID is F_2788."
#      Stats: Delay=4min | Food=5/5
#   #3 [Score: 0.7711]
#      Text: "A highly punctual medium-haul flight operating out of ORX. The flight departs from ORX and arrives at MCX. The Economy journey covered 1005 miles on a B757-300 aircraft. It arrived early by 15 minutes. The passenger (Generation: Silent, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is L9XXCM and Feedback ID is F_1355."
#      Stats: Delay=-15min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q11: Show me the delay for a flight out of JNX
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.8155]
#      Text: "A delayed medium-haul flight operating out of SNX. The flight departs from SNX and arrives at EWX. The Economy journey covered 3096 miles on a B757-200 aircraft. It had a moderate delay of 18 minutes. The passenger (Generation: Silent, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is PNXX92 and Feedback ID is F_311."
#      Stats: Delay=18min | Food=5/5
#   #2 [Score: 0.8154]
#      Text: "A delayed medium-haul flight operating out of SNX. The flight departs from SNX and arrives at IAX. The Economy journey covered 1347 miles on a B737-800 aircraft. It had a moderate delay of 19 minutes. The passenger (Generation: Boomer, Status: premier gold) reported a poor dining experience with a rating of 2/5. Passenger record locator is GDXXJZ and Feedback ID is F_1171."
#      Stats: Delay=19min | Food=2/5
#   #3 [Score: 0.8124]
#      Text: "A delayed medium-haul flight operating out of SNX. The flight departs from SNX and arrives at EWX. The Economy journey covered 2433 miles on a B737-700 aircraft. It had a moderate delay of 22 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is GMXX7L and Feedback ID is F_1216."
#      Stats: Delay=22min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8692]
#      Text: "A delayed short-haul flight operating out of IAX. The flight departs from IAX and arrives at QRX. The Economy journey covered 717 miles on a B737-700 aircraft. It had a moderate delay of 38 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is K3XXKN and Feedback ID is F_105."
#      Stats: Delay=38min | Food=3/5
#   #2 [Score: 0.8629]
#      Text: "A delayed medium-haul flight operating out of BQX. The flight departs from BQX and arrives at EWX. The Economy journey covered 1585 miles on a B737-900 aircraft. It had a moderate delay of 28 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is BDXX92 and Feedback ID is F_906."
#      Stats: Delay=28min | Food=2/5
#   #3 [Score: 0.8602]
#      Text: "A delayed short-haul flight operating out of IAX. The flight departs from IAX and arrives at PNX. The Economy journey covered 489 miles on a B737-700 aircraft. It had a moderate delay of 29 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is JYXXFZ and Feedback ID is F_1691."
#      Stats: Delay=29min | Food=2/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8265]
#      Text: "A delayed medium-haul flight operating out of HNX. The flight departs from HNX and arrives at DEX. The Economy journey covered 3365 miles on a B777-200 aircraft. It had a moderate delay of 26 minutes. The passenger (Generation: Boomer, Status: premier silver) reported a average dining experience with a rating of 3/5. Passenger record locator is J1XX77 and Feedback ID is F_1642."
#      Stats: Delay=26min | Food=3/5
#   #2 [Score: 0.8258]
#      Text: "A delayed medium-haul flight operating out of SNX. The flight departs from SNX and arrives at EWX. The Economy journey covered 3096 miles on a B757-200 aircraft. It had a moderate delay of 18 minutes. The passenger (Generation: Silent, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is PNXX92 and Feedback ID is F_311."
#      Stats: Delay=18min | Food=5/5
#   #3 [Score: 0.8240]
#      Text: "A severely delayed medium-haul flight operating out of HNX. The flight departs from HNX and arrives at DEX. The Economy journey covered 3365 miles on a B777-200 aircraft. It suffered a severe delay of 89 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a average dining experience with a rating of 3/5. Passenger record locator is FXXXLP and Feedback ID is F_449."
#      Stats: Delay=89min | Food=3/5
#
#
# ________________________________________________________________________________
# QUERY: Q12: Boomers who had excellent food
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6378]
# ...
#      Stats: Delay=8min | Food=1/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8316]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at SEX. The Economy journey covered 2401 miles on a B737-900 aircraft. It arrived early by 5 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is DPXXNQ and Feedback ID is F_636."
#      Stats: Delay=-5min | Food=1/5
#   #2 [Score: 0.8256]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at SEX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 19 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a poor dining experience with a rating of 1/5. Passenger record locator is LMXXC4 and Feedback ID is F_1367."
#      Stats: Delay=-19min | Food=1/5
#   #3 [Score: 0.8162]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at DEX. The Economy journey covered 1024 miles on a B737-900 aircraft. It arrived early by 20 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is F6XX47 and Feedback ID is F_2013."
#      Stats: Delay=-20min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8069]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at SEX. The Economy journey covered 2401 miles on a B737-900 aircraft. It arrived early by 5 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is DPXXNQ and Feedback ID is F_636."
#      Stats: Delay=-5min | Food=1/5
#   #2 [Score: 0.8041]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at SEX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 19 minutes. The passenger (Generation: Millennial, Status: premier silver) reported a poor dining experience with a rating of 1/5. Passenger record locator is LMXXC4 and Feedback ID is F_1367."
#      Stats: Delay=-19min | Food=1/5
#   #3 [Score: 0.8007]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at DEX. The Economy journey covered 1024 miles on a B737-900 aircraft. It arrived early by 20 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is F6XX47 and Feedback ID is F_2013."
#      Stats: Delay=-20min | Food=1/5
#
#
# ________________________________________________________________________________
# QUERY: Q17: Flights from SEX to IAX
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.7676]
#      Text: "A highly punctual medium-haul flight operating out of IAX. The flight departs from IAX and arrives at SNX. The Economy journey covered 1347 miles on a B737-700 aircraft. It arrived early by 13 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is EHXXX7 and Feedback ID is F_2481."
#      Stats: Delay=-13min | Food=3/5
#   #2 [Score: 0.7672]
#      Text: "A highly punctual medium-haul flight operating out of IAX. The flight departs from IAX and arrives at HNX. The Economy journey covered 3904 miles on a B777-200 aircraft. It arrived early by 1 minutes. The passenger (Generation: Silent, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is PFXXB2 and Feedback ID is F_2046."
#      Stats: Delay=-1min | Food=2/5
#   #3 [Score: 0.7651]
#      Text: "A highly punctual medium-haul flight operating out of IAX. The flight departs from IAX and arrives at HNX. The Economy journey covered 3904 miles on a B777-200 aircraft. It arrived early by 16 minutes. The passenger (Generation: Gen X, Status: premier 1k) reported a excellent dining experience with a rating of 5/5. Passenger record locator is OZXX0S and Feedback ID is F_1842."
#      Stats: Delay=-16min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.8556]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 6 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is JBXXKQ and Feedback ID is F_2480."
#      Stats: Delay=-6min | Food=5/5
#   #2 [Score: 0.8554]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 1874 miles on a B737-800 aircraft. It arrived early by 14 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is BSXX5B and Feedback ID is F_592."
#      Stats: Delay=-14min | Food=3/5
#   #3 [Score: 0.8539]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 1874 miles on a A320-200 aircraft. It arrived early by 16 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is FVXX4K and Feedback ID is F_410."
#      Stats: Delay=-16min | Food=4/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.8485]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 1874 miles on a B737-900 aircraft. It arrived early by 20 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a excellent dining experience with a rating of 4/5. Passenger record locator is GLXXYV and Feedback ID is F_1383."
#      Stats: Delay=-20min | Food=4/5
#   #2 [Score: 0.8452]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 1874 miles on a A320-200 aircraft. It arrived early by 16 minutes. The passenger (Generation: Millennial, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is FVXX4K and Feedback ID is F_410."
#      Stats: Delay=-16min | Food=4/5
#   #3 [Score: 0.8450]
#      Text: "A highly punctual medium-haul flight operating out of SEX. The flight departs from SEX and arrives at IAX. The Economy journey covered 2306 miles on a B737-900 aircraft. It arrived early by 6 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is JBXXKQ and Feedback ID is F_2480."
#      Stats: Delay=-6min | Food=5/5
#
#
# ________________________________________________________________________________
# QUERY: Q18: Pull up the record locator EPXXW8.
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6622]
#      Text: "A highly punctual long-haul flight operating out of HNX. The flight departs from HNX and arrives at EWX. The Economy journey covered 4962 miles on a B777-200 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is PQXXPR and Feedback ID is F_169."
#      Stats: Delay=-9min | Food=3/5
#   #2 [Score: 0.6568]
#      Text: "A severely delayed medium-haul flight operating out of EWX. The flight departs from EWX and arrives at SNX. The Economy journey covered 3096 miles on a B757-200 aircraft. It suffered a severe delay of 124 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is NZXXC7 and Feedback ID is F_1700."
#      Stats: Delay=124min | Food=2/5
#   #3 [Score: 0.6559]
#      Text: "A punctual medium-haul flight operating out of EWX. The flight departs from EWX and arrives at SNX. The Economy journey covered 3096 miles on a B757-200 aircraft. It was roughly on time (3 min delay). The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is C6XXK5 and Feedback ID is F_828."
#      Stats: Delay=3min | Food=2/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6594]
#      Text: "A highly punctual short-haul flight operating out of EWX. The flight departs from EWX and arrives at SAX. The Economy journey covered 708 miles on a ERJ-175 aircraft. It arrived early by 13 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is PCXXHN and Feedback ID is F_525."
#      Stats: Delay=-13min | Food=2/5
#   #2 [Score: 0.6580]
#      Text: "A highly punctual short-haul flight operating out of EWX. The flight departs from EWX and arrives at SAX. The Economy journey covered 708 miles on a ERJ-175 aircraft. It arrived early by 22 minutes. The passenger (Generation: Silent, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is PJXXN3 and Feedback ID is F_1255."
#      Stats: Delay=-22min | Food=3/5
#   #3 [Score: 0.6569]
#      Text: "A highly punctual medium-haul flight operating out of EWX. The flight departs from EWX and arrives at SAX. The Economy journey covered 2425 miles on a B737-800 aircraft. It arrived early by 6 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is ITXX1X and Feedback ID is F_488."
#      Stats: Delay=-6min | Food=5/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7900]
#      Text: "A highly punctual short-haul flight operating out of EWX. The flight departs from EWX and arrives at PQX. The Economy journey covered 515 miles on a CRJ-550 aircraft. It arrived early by 19 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is JEXXH2 and Feedback ID is F_1754."
#      Stats: Delay=-19min | Food=5/5
#   #2 [Score: 0.7893]
#      Text: "A highly punctual short-haul flight operating out of EWX. The flight departs from EWX and arrives at PWX. The Economy journey covered 284 miles on a ERJ-175 aircraft. It arrived early by 8 minutes. The passenger (Generation: Silent, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is D4XX3Z and Feedback ID is F_2176."
#      Stats: Delay=-8min | Food=4/5
#   #3 [Score: 0.7873]
#      Text: "A highly punctual short-haul flight operating out of EWX. The flight departs from EWX and arrives at TPX. The Economy journey covered 998 miles on a B737-MAX8 aircraft. It arrived early by 31 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is F1XXWK and Feedback ID is F_2139."
#      Stats: Delay=-31min | Food=4/5
#
#
# ________________________________________________________________________________
# QUERY: Q18: Pull up the feedback ID F_18.
# ________________________________________________________________________________
#
# --- MODEL: MINILM ---
#   #1 [Score: 0.6072]
#      Text: "A highly punctual long-haul flight operating out of FCX. The flight departs from FCX and arrives at ORX. The Economy journey covered 4823 miles on a B787-8 aircraft. It arrived early by 28 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a excellent dining experience with a rating of 4/5. Passenger record locator is OQXXSP and Feedback ID is F_936."
#      Stats: Delay=-28min | Food=4/5
#   #2 [Score: 0.6068]
#      Text: "A punctual long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It was roughly on time (11 min delay). The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is I7XXMV and Feedback ID is F_2030."
#      Stats: Delay=11min | Food=3/5
#   #3 [Score: 0.6054]
#      Text: "A severely delayed long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It suffered a severe delay of 62 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a excellent dining experience with a rating of 5/5. Passenger record locator is K0XX2X and Feedback ID is F_2928."
#      Stats: Delay=62min | Food=5/5
#
# --- MODEL: MPNET ---
#   #1 [Score: 0.6581]
#      Text: "A highly punctual short-haul flight operating out of FCX. The flight departs from FCX and arrives at DEX. The Economy journey covered 753 miles on a B737-800 aircraft. It arrived early by 9 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is IEXX6W and Feedback ID is F_1510."
#      Stats: Delay=-9min | Food=2/5
#   #2 [Score: 0.6532]
#      Text: "A highly punctual short-haul flight operating out of FSX. The flight departs from FSX and arrives at DEX. The Economy journey covered 483 miles on a ERJ-175 aircraft. It arrived early by 19 minutes. The passenger (Generation: Gen X, Status: non-elite) reported a average dining experience with a rating of 3/5. Passenger record locator is BRXXY0 and Feedback ID is F_495."
#      Stats: Delay=-19min | Food=3/5
#   #3 [Score: 0.6521]
#      Text: "A highly punctual short-haul flight operating out of LGX. The flight departs from LGX and arrives at ORX. The Economy journey covered 733 miles on a A320-200 aircraft. It arrived early by 5 minutes. The passenger (Generation: Gen X, Status: premier gold) reported a poor dining experience with a rating of 1/5. Passenger record locator is H0XXV6 and Feedback ID is F_204."
#      Stats: Delay=-5min | Food=1/5
#
# --- MODEL: BGE-M3 ---
#   #1 [Score: 0.7449]
#      Text: "A delayed long-haul flight operating out of IAX. The flight departs from IAX and arrives at FCX. The Economy journey covered 4505 miles on a B787-8 aircraft. It had a moderate delay of 18 minutes. The passenger (Generation: Boomer, Status: non-elite) reported a poor dining experience with a rating of 2/5. Passenger record locator is F2XXEM and Feedback ID is F_2371."
#      Stats: Delay=18min | Food=2/5
#   #2 [Score: 0.7430]
#      Text: "A punctual short-haul flight operating out of PIX. The flight departs from PIX and arrives at IAX. The Economy journey covered 183 miles on a ERJ-175 aircraft. It was roughly on time (7 min delay). The passenger (Generation: Millennial, Status: non-elite) reported a poor dining experience with a rating of 1/5. Passenger record locator is IEXXEB and Feedback ID is F_163."
#      Stats: Delay=7min | Food=1/5
#   #3 [Score: 0.7428]
#      Text: "A punctual long-haul flight operating out of FCX. The flight departs from FCX and arrives at IAX. The Economy journey covered 4505 miles on a B787-8 aircraft. It was roughly on time (11 min delay). The passenger (Generation: Millennial, Status: premier silver) reported a poor dining experience with a rating of 1/5. Passenger record locator is LGXXG0 and Feedback ID is F_2961."
#      Stats: Delay=11min | Food=1/5

# %% [markdown]
# #### Deleting vectors and indices to restart with diff embeddings

# %%
# from neo4j import GraphDatabase
# import os
# from dotenv import load_dotenv

# # Load environment variables
# load_dotenv()

# # Neo4j Connection
# uri = os.getenv('NEO4J_URI', 'neo4j://localhost:7687')
# username = os.getenv('NEO4J_USERNAME', 'neo4j')
# password = os.getenv('NEO4J_PASSWORD', 'password')

# driver = GraphDatabase.driver(uri, auth=(username, password))

# def clean_slate():
#     with driver.session() as session:
#         print("--- Starting Cleanup ---")
        
#         # 1. Drop the Vector Indices
#         # We drop them individually to ensure no conflicts when re-creating
#         indices_to_drop = [
#             "journey_minilm_full_index", # From your old script name
#             "journey_mpnet_full_index",  # From your old script name
#             "journey_bge_m3_index",      # From your old script name
#             "minilm_vec_index",          # From new script name
#             "mpnet_vec_index",           # From new script name
#             "bgem3_vec_index"            # From new script name
#         ]
        
#         for index in indices_to_drop:
#             try:
#                 print(f"Dropping index: {index}...")
#                 session.run(f"DROP INDEX {index} IF EXISTS")
#             except Exception as e:
#                 print(f"Could not drop {index}: {e}")

#         # 2. Delete the Nodes
#         # DETACH DELETE removes the node AND its relationships (e.g., HAS_VECTOR)
#         print("Deleting all :JourneyVector nodes...")
#         result = session.run("""
#             MATCH (n:JourneyVector)
#             DETACH DELETE n
#             RETURN count(n) as count
#         """)
#         count = result.single()["count"]
#         print(f"Deleted {count} JourneyVector nodes.")
        
#         # Optional: Clean up old properties on Journey nodes if you ran the old script
#         print("Cleaning up old vector properties on :Journey nodes (if any)...")
#         session.run("""
#             MATCH (j:Journey)
#             REMOVE j.full_feature_text, 
#                    j.embedding_minilm_full, 
#                    j.embedding_mpnet_full, 
#                    j.embedding_bge_m3_full
#         """)
#         print("Cleanup complete.")

# if __name__ == "__main__":
#     clean_slate()
#     driver.close()

# %% [markdown]
# ### New report after improvements to text sentiment

# %% [markdown]
# ###  Airline Embedding Models Re-Evaluation Report
#
# ### 1. What Improved? (The "Keyword Stuffing" Effect)
# The changes made to the text generation strategy specifically adding *"operating out of [Origin]"*, *"departs from X and arrives at Y"*, and explicit IDs have yielded **drastic improvements** in retrieval quality compared to the first run.
#
# * **Route Accuracy is now near 100%:**
#     * *Previously:* Models struggled to distinguish Origin from Destination.
#     * *Now:* In **Q14** ("Flights from JNX to EWX") and **Q16** ("Flights out of SEX"), **ALL three models** successfully retrieved flights matching the specific airport codes. The phrasing *"operating out of SEX"* created a strong semantic hook that even the smaller MiniLM model could catch.
# * **Semantic Richness:**
#     * The generated text matches user queries much more naturally. When a user asks for "severe delays" or "big delays", the models now find text that explicitly says "suffered a severe delay", leading to higher confidence scores (0.80+ for MPNet/BGE-M3).
#
# ### 2. The "ID Lookup" Limitation
# *Tests: Q18 (Record EPXXW8) and Q19 (Feedback F_18)*
#
# **Notice:** Despite adding *"Passenger record locator is EPXXW8"* to the text, **NONE of the models found the exact record in the top 3 results.**
# * **Why?** Vector embeddings capture *semantic meaning*, not exact character matching. To a language model, the random string `EPXXW8` looks semantically identical to `PQXXPR` or `NZXXC7` they are just "alphanumeric codes."
# * **The Takeaway:** This validates your system architecture. **we cannot rely on Vector Search for ID lookups.** We **must** use the Router (Intent Classification) to send ID queries to **Cypher** (exact match), while reserving Vector Search for qualitative queries ("bad food", "delays").
#
# ---
#
# ### 3. Model Comparisons
#
# #### 🥇 Winner: BGE-M3 (BAAI/bge-m3)
# * **Performance:** Consistently the highest confidence scores (often >0.82).
# * **Route Handling:** It handled the "Flights out of SEX" query perfectly, returning multiple flights departing from that exact station.
# * **Nuance:** It showed the best balance in **Q6** ("Great food but late flight"), finding flights with high delays but 5/5 food scores, whereas others struggled to balance the contradicting sentiments.
# * **Verdict:** **The Best Choice.** It behaves most like a "Hybrid" retriever, respecting keywords while understanding sentiment.
#
# #### 🥈 Runner Up: MPNet (paraphrase-mpnet-base-v2)
# * **Performance:** Very strong on descriptive queries (Q1, Q9). It understands "Nightmare journey" very well.
# * **Improvement:** It significantly improved on Airport Codes compared to the previous run, thanks to the new text templates.
# * **Verdict:** A solid backup, but slightly less precise than BGE-M3 on edge-case entity matching.
#
# #### 🥉 Third Place: MiniLM (all-MiniLM-L6-v2)
# * **Performance:** Fastest, but lowest confidence scores (~0.60 - 0.75).
# * **Surprise Win:** It actually handled the Route queries (Q14, Q16) correctly this time! The "operating out of" phrasing helped this small model bridge the gap.
# * **Verdict:** Usable if hardware resources are very tight, but significantly less "smart" than BGE-M3.
#
# ---
#
#
# ### Visual Architecture Update
# The failure of vector search to find exact IDs validates this flow:
#
#
#
# 1.  **Input:** "Record EPXXW8"
# 2.  **Intent Classifier:** Detects `lookup_details`
# 3.  **Path:** Skips Vector Index $\rightarrow$ Executes Cypher Exact Match.
